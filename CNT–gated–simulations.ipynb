# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy as sp
import csv
import matplotlib.patches as mpatches
import pandas as pd
import matplotlib.ticker as mtick
import matplotlib.tri as mtri

# %%
################# 2 nm ############

CNT_2_nm_Vd_1_dr = pd.read_csv("CNT_radii/2_nm/CNT_2_nm_rad_Vd_1_drain.csv")
x_CNT_2_nm_Vd_1_dr = CNT_2_nm_Vd_1_dr['x']
y_CNT_2_nm_Vd_1_dr = CNT_2_nm_Vd_1_dr['y']

CNT_2_nm_Vd_1_lk = pd.read_csv("CNT_radii/2_nm/CNT_2_nm_rad_Vd_1_leak.csv")
x_CNT_2_nm_Vd_1_lk = CNT_2_nm_Vd_1_lk['x']
y_CNT_2_nm_Vd_1_lk = CNT_2_nm_Vd_1_lk['y']

CNT_2_nm_Vd_1p5_dr = pd.read_csv("CNT_radii/2_nm/CNT_2_nm_rad_Vd_1p5_drain.csv")
x_CNT_2_nm_Vd_1p5_dr = CNT_2_nm_Vd_1p5_dr['x']
y_CNT_2_nm_Vd_1p5_dr = CNT_2_nm_Vd_1p5_dr['y']

CNT_2_nm_Vd_1p5_lk = pd.read_csv("CNT_radii/2_nm/CNT_2_nm_rad_Vd_1p5_leak.csv")
x_CNT_2_nm_Vd_1p5_lk = CNT_2_nm_Vd_1p5_lk['x']
y_CNT_2_nm_Vd_1p5_lk = CNT_2_nm_Vd_1p5_lk['y']

CNT_2_nm_Vd_2_dr = pd.read_csv("CNT_radii/2_nm/CNT_2_nm_rad_Vd_2_drain.csv")
x_CNT_2_nm_Vd_2_dr = CNT_2_nm_Vd_2_dr['x']
y_CNT_2_nm_Vd_2_dr = CNT_2_nm_Vd_2_dr['y']

CNT_2_nm_Vd_2_lk = pd.read_csv("CNT_radii/2_nm/CNT_2_nm_rad_Vd_2_leak.csv")
x_CNT_2_nm_Vd_2_lk = CNT_2_nm_Vd_2_lk['x']
y_CNT_2_nm_Vd_2_lk = CNT_2_nm_Vd_2_lk['y']

CNT_2_nm_Vd_2p5_dr = pd.read_csv("CNT_radii/2_nm/CNT_2_nm_rad_Vd_2p5_drain.csv")
x_CNT_2_nm_Vd_2p5_dr = CNT_2_nm_Vd_2p5_dr['x']
y_CNT_2_nm_Vd_2p5_dr = CNT_2_nm_Vd_2p5_dr['y']

CNT_2_nm_Vd_2p5_lk = pd.read_csv("CNT_radii/2_nm/CNT_2_nm_rad_Vd_2p5_leak.csv")
x_CNT_2_nm_Vd_2p5_lk = CNT_2_nm_Vd_2p5_lk['x']
y_CNT_2_nm_Vd_2p5_lk = CNT_2_nm_Vd_2p5_lk['y']

################# 3 nm ############

CNT_3_nm_Vd_1_dr = pd.read_csv("CNT_radii/3_nm/CNT_3_nm_rad_Vd_1_drain.csv")
x_CNT_3_nm_Vd_1_dr = CNT_3_nm_Vd_1_dr['x']
y_CNT_3_nm_Vd_1_dr = CNT_3_nm_Vd_1_dr['y']

CNT_3_nm_Vd_1_lk = pd.read_csv("CNT_radii/3_nm/CNT_3_nm_rad_Vd_1_leak.csv")
x_CNT_3_nm_Vd_1_lk = CNT_3_nm_Vd_1_lk['x']
y_CNT_3_nm_Vd_1_lk = CNT_3_nm_Vd_1_lk['y']

CNT_3_nm_Vd_1p5_dr = pd.read_csv("CNT_radii/3_nm/CNT_3_nm_rad_Vd_1p5_drain.csv")
x_CNT_3_nm_Vd_1p5_dr = CNT_3_nm_Vd_1p5_dr['x']
y_CNT_3_nm_Vd_1p5_dr = CNT_3_nm_Vd_1p5_dr['y']

CNT_3_nm_Vd_1p5_lk = pd.read_csv("CNT_radii/3_nm/CNT_3_nm_rad_Vd_1p5_leak.csv")
x_CNT_3_nm_Vd_1p5_lk = CNT_3_nm_Vd_1p5_lk['x']
y_CNT_3_nm_Vd_1p5_lk = CNT_3_nm_Vd_1p5_lk['y']

CNT_3_nm_Vd_2_dr = pd.read_csv("CNT_radii/3_nm/CNT_3_nm_rad_Vd_2_drain.csv")
x_CNT_3_nm_Vd_2_dr = CNT_3_nm_Vd_2_dr['x']
y_CNT_3_nm_Vd_2_dr = CNT_3_nm_Vd_2_dr['y']

CNT_3_nm_Vd_2_lk = pd.read_csv("CNT_radii/3_nm/CNT_3_nm_rad_Vd_2_leak.csv")
x_CNT_3_nm_Vd_2_lk = CNT_3_nm_Vd_2_lk['x']
y_CNT_3_nm_Vd_2_lk = CNT_3_nm_Vd_2_lk['y']

CNT_3_nm_Vd_2p5_dr = pd.read_csv("CNT_radii/3_nm/CNT_3_nm_rad_Vd_2p5_drain.csv")
x_CNT_3_nm_Vd_2p5_dr = CNT_3_nm_Vd_2p5_dr['x']
y_CNT_3_nm_Vd_2p5_dr = CNT_3_nm_Vd_2p5_dr['y']

CNT_3_nm_Vd_2p5_lk = pd.read_csv("CNT_radii/3_nm/CNT_3_nm_rad_Vd_2p5_leak.csv")
x_CNT_3_nm_Vd_2p5_lk = CNT_3_nm_Vd_2p5_lk['x']
y_CNT_3_nm_Vd_2p5_lk = CNT_3_nm_Vd_2p5_lk['y']

################# 4 nm ############

CNT_4_nm_Vd_1_dr = pd.read_csv("CNT_radii/4_nm/CNT_4_nm_rad_Vd_1_drain.csv")
x_CNT_4_nm_Vd_1_dr = CNT_4_nm_Vd_1_dr['x']
y_CNT_4_nm_Vd_1_dr = CNT_4_nm_Vd_1_dr['y']

CNT_4_nm_Vd_1_lk = pd.read_csv("CNT_radii/4_nm/CNT_4_nm_rad_Vd_1_leak.csv")
x_CNT_4_nm_Vd_1_lk = CNT_4_nm_Vd_1_lk['x']
y_CNT_4_nm_Vd_1_lk = CNT_4_nm_Vd_1_lk['y']

CNT_4_nm_Vd_1p5_dr = pd.read_csv("CNT_radii/4_nm/CNT_4_nm_rad_Vd_1p5_drain.csv")
x_CNT_4_nm_Vd_1p5_dr = CNT_4_nm_Vd_1p5_dr['x']
y_CNT_4_nm_Vd_1p5_dr = CNT_4_nm_Vd_1p5_dr['y']

CNT_4_nm_Vd_1p5_lk = pd.read_csv("CNT_radii/4_nm/CNT_4_nm_rad_Vd_1p5_leak.csv")
x_CNT_4_nm_Vd_1p5_lk = CNT_4_nm_Vd_1p5_lk['x']
y_CNT_4_nm_Vd_1p5_lk = CNT_4_nm_Vd_1p5_lk['y']

CNT_4_nm_Vd_2_dr = pd.read_csv("CNT_radii/4_nm/CNT_4_nm_rad_Vd_2_drain.csv")
x_CNT_4_nm_Vd_2_dr = CNT_4_nm_Vd_2_dr['x']
y_CNT_4_nm_Vd_2_dr = CNT_4_nm_Vd_2_dr['y']

CNT_4_nm_Vd_2_lk = pd.read_csv("CNT_radii/4_nm/CNT_4_nm_rad_Vd_2_leak.csv")
x_CNT_4_nm_Vd_2_lk = CNT_4_nm_Vd_2_lk['x']
y_CNT_4_nm_Vd_2_lk = CNT_4_nm_Vd_2_lk['y']

CNT_4_nm_Vd_2p5_dr = pd.read_csv("CNT_radii/4_nm/CNT_4_nm_rad_Vd_2p5_drain.csv")
x_CNT_4_nm_Vd_2p5_dr = CNT_4_nm_Vd_2p5_dr['x']
y_CNT_4_nm_Vd_2p5_dr = CNT_4_nm_Vd_2p5_dr['y']

CNT_4_nm_Vd_2p5_lk = pd.read_csv("CNT_radii/4_nm/CNT_4_nm_rad_Vd_2p5_leak.csv")
x_CNT_4_nm_Vd_2p5_lk = CNT_4_nm_Vd_2p5_lk['x']
y_CNT_4_nm_Vd_2p5_lk = CNT_4_nm_Vd_2p5_lk['y']

############### 5 nm ################


CNT_5_nm_Vd_1_dr = pd.read_csv("CNT_radii/5_nm/CNT_5_nm_rad_Vd_1_drain.csv")
x_CNT_5_nm_Vd_1_dr = CNT_5_nm_Vd_1_dr['x']
y_CNT_5_nm_Vd_1_dr = CNT_5_nm_Vd_1_dr['y']

CNT_5_nm_Vd_1_lk = pd.read_csv("CNT_radii/5_nm/CNT_5_nm_rad_Vd_1_leak.csv")
x_CNT_5_nm_Vd_1_lk = CNT_5_nm_Vd_1_lk['x']
y_CNT_5_nm_Vd_1_lk = CNT_5_nm_Vd_1_lk['y']

CNT_5_nm_Vd_1p5_dr = pd.read_csv("CNT_radii/5_nm/CNT_5_nm_rad_Vd_1p5_drain.csv")
x_CNT_5_nm_Vd_1p5_dr = CNT_5_nm_Vd_1p5_dr['x']
y_CNT_5_nm_Vd_1p5_dr = CNT_5_nm_Vd_1p5_dr['y']

CNT_5_nm_Vd_1p5_lk = pd.read_csv("CNT_radii/5_nm/CNT_5_nm_rad_Vd_1p5_leak.csv")
x_CNT_5_nm_Vd_1p5_lk = CNT_5_nm_Vd_1p5_lk['x']
y_CNT_5_nm_Vd_1p5_lk = CNT_5_nm_Vd_1p5_lk['y']

CNT_5_nm_Vd_2_dr = pd.read_csv("CNT_radii/5_nm/CNT_5_nm_rad_Vd_2_drain.csv")
x_CNT_5_nm_Vd_2_dr = CNT_5_nm_Vd_2_dr['x']
y_CNT_5_nm_Vd_2_dr = CNT_5_nm_Vd_2_dr['y']

CNT_5_nm_Vd_2_lk = pd.read_csv("CNT_radii/5_nm/CNT_5_nm_rad_Vd_2_leak.csv")
x_CNT_5_nm_Vd_2_lk = CNT_5_nm_Vd_2_lk['x']
y_CNT_5_nm_Vd_2_lk = CNT_5_nm_Vd_2_lk['y']

CNT_5_nm_Vd_2p5_dr = pd.read_csv("CNT_radii/5_nm/CNT_5_nm_rad_Vd_2p5_drain.csv")
x_CNT_5_nm_Vd_2p5_dr = CNT_5_nm_Vd_2p5_dr['x']
y_CNT_5_nm_Vd_2p5_dr = CNT_5_nm_Vd_2p5_dr['y']

CNT_5_nm_Vd_2p5_lk = pd.read_csv("CNT_radii/5_nm/CNT_5_nm_rad_Vd_2p5_leak.csv")
x_CNT_5_nm_Vd_2p5_lk = CNT_5_nm_Vd_2p5_lk['x']
y_CNT_5_nm_Vd_2p5_lk = CNT_5_nm_Vd_2p5_lk['y']

############### 10 nm ################


CNT_10_nm_Vd_1_dr = pd.read_csv("CNT_radii/10_nm/CNT_10_nm_rad_Vd_1_drain.csv")
x_CNT_10_nm_Vd_1_dr = CNT_10_nm_Vd_1_dr['x']
y_CNT_10_nm_Vd_1_dr = CNT_10_nm_Vd_1_dr['y']

CNT_10_nm_Vd_1_lk = pd.read_csv("CNT_radii/10_nm/CNT_10_nm_rad_Vd_1_leak.csv")
x_CNT_10_nm_Vd_1_lk = CNT_10_nm_Vd_1_lk['x']
y_CNT_10_nm_Vd_1_lk = CNT_10_nm_Vd_1_lk['y']

CNT_10_nm_Vd_1p5_dr = pd.read_csv("CNT_radii/10_nm/CNT_10_nm_rad_Vd_1p5_drain.csv")
x_CNT_10_nm_Vd_1p5_dr = CNT_10_nm_Vd_1p5_dr['x']
y_CNT_10_nm_Vd_1p5_dr = CNT_10_nm_Vd_1p5_dr['y']

CNT_10_nm_Vd_1p5_lk = pd.read_csv("CNT_radii/10_nm/CNT_10_nm_rad_Vd_1p5_leak.csv")
x_CNT_10_nm_Vd_1p5_lk = CNT_10_nm_Vd_1p5_lk['x']
y_CNT_10_nm_Vd_1p5_lk = CNT_10_nm_Vd_1p5_lk['y']

CNT_10_nm_Vd_2_dr = pd.read_csv("CNT_radii/10_nm/CNT_10_nm_rad_Vd_2_drain.csv")
x_CNT_10_nm_Vd_2_dr = CNT_10_nm_Vd_2_dr['x']
y_CNT_10_nm_Vd_2_dr = CNT_10_nm_Vd_2_dr['y']

CNT_10_nm_Vd_2_lk = pd.read_csv("CNT_radii/10_nm/CNT_10_nm_rad_Vd_2_leak.csv")
x_CNT_10_nm_Vd_2_lk = CNT_10_nm_Vd_2_lk['x']
y_CNT_10_nm_Vd_2_lk = CNT_10_nm_Vd_2_lk['y']

CNT_10_nm_Vd_2p5_dr = pd.read_csv("CNT_radii/10_nm/CNT_10_nm_rad_Vd_2p5_drain.csv")
x_CNT_10_nm_Vd_2p5_dr = CNT_10_nm_Vd_2p5_dr['x']
y_CNT_10_nm_Vd_2p5_dr = CNT_10_nm_Vd_2p5_dr['y']

CNT_10_nm_Vd_2p5_lk = pd.read_csv("CNT_radii/10_nm/CNT_10_nm_rad_Vd_2p5_leak.csv")
x_CNT_10_nm_Vd_2p5_lk = CNT_10_nm_Vd_2p5_lk['x']
y_CNT_10_nm_Vd_2p5_lk = CNT_10_nm_Vd_2p5_lk['y']

# %%
fig = plt.figure(figsize=(5,5))

ax1 = fig.add_subplot(111)

ax1.set_xlabel('V$_g$ [V]', fontsize = 15)
ax1.set_ylabel('Current [A]', fontsize = 15)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
ax1.set_facecolor('#f2f7ff')
#from matplotlib import ticker
#formatter = ticker.ScalarFormatter(useMathText=True)
#formatter.set_scientific(True)
#formatter.set_powerlimits((-1,1))
#axes.yaxis.set_major_formatter(formatter)


xticks = [0, 0.5, 1, 1.5, 2]
ax1.set_title("CNT diameter = 2 nm; $V_D$ = 1 V\n", fontsize = 14)
#axes.grid('off')
#axes.set_yticks(axes.get_yticks()[::1])
ax1.set_xticks(xticks)
#ax1.set_ylim([1e-12, 1e-8])
#ax1.text(0.8, 2.5e-9, "CNT diameter = 2 nm\n\n     $V_D$ = 1 V", fontsize = 14)
#ax1.set_yscale('log')
#ax1.set_xlim([0.01,1])
ax1.plot(x_CNT_2_nm_Vd_1_dr, y_CNT_2_nm_Vd_1_dr, 'o', ms = 7, color='forestgreen', linestyle='-',
         mew = 0.5, mec = 'black',linewidth=2, label = '$I_D$')
ax1.plot(x_CNT_2_nm_Vd_1_lk, y_CNT_2_nm_Vd_1_lk, 'o', ms = 7, color='tomato', linestyle='-',
         mew = 0.5, mec = 'black',linewidth=2, label = 'Gate Leakage')
#ax1.fill_between(x_CNT_2_nm_Vd_1_lk[0:121],y_CNT_2_nm_Vd_1_dr[0:121],y_CNT_2_nm_Vd_1_lk[0:121], color = 'steelblue')

ax1.legend(loc='best',ncol=1, fontsize = 14)


plt.savefig("CNT_radii/2_nm/Vd_1.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(10,10))

ax1 = fig.add_subplot(221)

ax1.set_xlabel('V$_g$ [V]', fontsize = 15)
ax1.set_ylabel('Current [A]', fontsize = 15)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
ax1.set_facecolor('#f2f7ff')

xticks = [0, 0.5, 1, 1.5, 2]
ax1.set_title("CNT diameter = 2 nm; $V_D$ = 1.0 V\n", fontsize = 14)
#axes.grid('off')
#axes.set_yticks(axes.get_yticks()[::1])
ax1.set_xticks(xticks)
#ax1.set_ylim([1e-12, 1e-8])
#ax1.text(0.8, 2.5e-9, "CNT diameter = 2 nm\n\n     $V_D$ = 1 V", fontsize = 14)
#ax1.set_yscale('log')
#ax1.set_xlim([0.01,1])
ax1.plot(x_CNT_2_nm_Vd_1_dr, y_CNT_2_nm_Vd_1_dr, 'o', ms = 7, color='forestgreen', linestyle='-',
         mew = 0.5, mec = 'black',linewidth=2, label = '$I_D$')
ax1.plot(x_CNT_2_nm_Vd_1_lk, y_CNT_2_nm_Vd_1_lk, 'o', ms = 7, color='tomato', linestyle='-',
         mew = 0.5, mec = 'black',linewidth=2, label = 'Gate Leakage')
#ax1.fill_between(x_CNT_2_nm_Vd_1_lk[0:121],y_CNT_2_nm_Vd_1_dr[0:121],y_CNT_2_nm_Vd_1_lk[0:121], color = 'steelblue')


ax2 = fig.add_subplot(222)

ax2.set_xlabel('V$_g$ [V]', fontsize = 15)
ax2.set_ylabel('Current [A]', fontsize = 15)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
ax2.set_facecolor('#f2f7ff')

xticks = [0, 0.5, 1, 1.5, 2]
ax2.set_title("CNT diameter = 2 nm; $V_D$ = 1.5 V\n", fontsize = 14)
#axes.grid('off')
#axes.set_yticks(axes.get_yticks()[::1])
ax2.set_xticks(xticks)
#ax2.set_ylim([1e-12, 1e-8])
#ax2.text(0.8, 2.5e-9, "CNT diameter = 2 nm\n\n     $V_D$ = 1 V", fontsize = 14)
#ax2.set_yscale('log')
#ax2.set_xlim([0.01,1])
ax2.plot(x_CNT_2_nm_Vd_1p5_dr, y_CNT_2_nm_Vd_1p5_dr, 'o', ms = 7, color='forestgreen', linestyle='-',
         mew = 0.5, mec = 'black',linewidth=2, label = '$I_D$')
ax2.plot(x_CNT_2_nm_Vd_1p5_lk, y_CNT_2_nm_Vd_1p5_lk, 'o', ms = 7, color='tomato', linestyle='-',
         mew = 0.5, mec = 'black',linewidth=2, label = 'Gate Leakage')
#ax2.fill_between(x_CNT_2_nm_Vd_1_lk[0:121],y_CNT_2_nm_Vd_1_dr[0:121],y_CNT_2_nm_Vd_1_lk[0:121], color = 'steelblue')

ax3 = fig.add_subplot(223)

ax3.set_xlabel('V$_g$ [V]', fontsize = 15)
ax3.set_ylabel('Current [A]', fontsize = 15)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
ax3.set_facecolor('#f2f7ff')

xticks = [0, 0.5, 1, 1.5, 2]
ax3.set_title("CNT diameter = 2 nm; $V_D$ = 2 V\n", fontsize = 14)
#axes.grid('off')
#axes.set_yticks(axes.get_yticks()[::1])
ax3.set_xticks(xticks)
#ax3.set_ylim([1e-12, 1e-8])
#ax3.text(0.8, 2.5e-9, "CNT diameter = 2 nm\n\n     $V_D$ = 1 V", fontsize = 14)
#ax3.set_yscale('log')
ax3.set_xlim([0.02,2])
ax3.plot(x_CNT_2_nm_Vd_2_dr, y_CNT_2_nm_Vd_2_dr, 'o', ms = 7, color='forestgreen', linestyle='-',
         mew = 0.5, mec = 'black',linewidth=2, label = '$I_D$')
ax3.plot(x_CNT_2_nm_Vd_2_lk, y_CNT_2_nm_Vd_2_lk, 'o', ms = 7, color='tomato', linestyle='-',
         mew = 0.5, mec = 'black',linewidth=2, label = 'Gate Leakage')
#ax3.fill_between(x_CNT_2_nm_Vd_1_lk[0:121],y_CNT_2_nm_Vd_1_dr[0:121],y_CNT_2_nm_Vd_1_lk[0:121], color = 'steelblue')

ax4 = fig.add_subplot(224)

ax4.set_xlabel('V$_g$ [V]', fontsize = 15)
ax4.set_ylabel('Current [A]', fontsize = 15)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
ax4.set_facecolor('#f2f7ff')

xticks = [0, 0.5, 1, 1.5, 2]
ax4.set_title("CNT diameter = 2 nm; $V_D$ = 2.5 V\n", fontsize = 14)
#axes.grid('off')
#axes.set_yticks(axes.get_yticks()[::1])
ax4.set_xticks(xticks)
#ax4.set_ylim([1e-12, 1e-8])
#ax4.text(0.8, 2.5e-9, "CNT diameter = 2 nm\n\n     $V_D$ = 1 V", fontsize = 14)
#ax4.set_yscale('log')
ax4.set_xlim([0.02,2])
ax4.plot(x_CNT_2_nm_Vd_2p5_dr, y_CNT_2_nm_Vd_2p5_dr, 'o', ms = 7, color='forestgreen', linestyle='-',
         mew = 0.5, mec = 'black',linewidth=2, label = '$I_D$')
ax4.plot(x_CNT_2_nm_Vd_2p5_lk, y_CNT_2_nm_Vd_2p5_lk, 'o', ms = 7, color='tomato', linestyle='-',
         mew = 0.5, mec = 'black',linewidth=2, label = 'Gate Leakage')
#ax4.fill_between(x_CNT_2_nm_Vd_1_lk[0:121],y_CNT_2_nm_Vd_1_dr[0:121],y_CNT_2_nm_Vd_1_lk[0:121], color = 'steelblue')

ax1.legend(loc='best',ncol=1, fontsize = 12)
#ax2.legend(loc='best',ncol=1, fontsize = 12)
#ax3.legend(loc='best',ncol=1, fontsize = 12)
#ax4.legend(loc='best',ncol=1, fontsize = 12)

plt.tight_layout()
plt.savefig("CNT_radii/2_nm/Vd_grid.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(10,10))

ax1 = fig.add_subplot(221)

ax1.set_xlabel('V$_g$ [V]', fontsize = 15)
ax1.set_ylabel('Current [A]', fontsize = 15)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
ax1.set_facecolor('#f2f7ff')

xticks = [0, 0.5, 1, 1.5, 2]
ax1.set_title("CNT diameter = 3 nm; $V_D$ = 1.0 V\n", fontsize = 14)
#axes.grid('off')
#axes.set_yticks(axes.get_yticks()[::1])
ax1.set_xticks(xticks)
#ax1.set_ylim([1e-12, 1e-8])
#ax1.text(0.8, 2.5e-9, "CNT diameter = 2 nm\n\n     $V_D$ = 1 V", fontsize = 14)
#ax1.set_yscale('log')
#ax1.set_xlim([0.01,1])
ax1.plot(x_CNT_3_nm_Vd_1_dr, y_CNT_3_nm_Vd_1_dr, 'o', ms = 7, color='forestgreen', linestyle='-',
         mew = 0.5, mec = 'black',linewidth=2, label = '$I_D$')
ax1.plot(x_CNT_3_nm_Vd_1_lk, y_CNT_3_nm_Vd_1_lk, 'o', ms = 7, color='tomato', linestyle='-',
         mew = 0.5, mec = 'black',linewidth=2, label = 'Gate Leakage')
#ax1.fill_between(x_CNT_2_nm_Vd_1_lk[0:121],y_CNT_2_nm_Vd_1_dr[0:121],y_CNT_2_nm_Vd_1_lk[0:121], color = 'steelblue')


ax2 = fig.add_subplot(222)

ax2.set_xlabel('V$_g$ [V]', fontsize = 15)
ax2.set_ylabel('Current [A]', fontsize = 15)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
ax2.set_facecolor('#f2f7ff')

xticks = [0, 0.5, 1, 1.5, 2]
ax2.set_title("CNT diameter = 3 nm; $V_D$ = 1.5 V\n", fontsize = 14)
#axes.grid('off')
#axes.set_yticks(axes.get_yticks()[::1])
ax2.set_xticks(xticks)
#ax2.set_ylim([1e-12, 1e-8])
#ax2.text(0.8, 2.5e-9, "CNT diameter = 2 nm\n\n     $V_D$ = 1 V", fontsize = 14)
#ax2.set_yscale('log')
#ax2.set_xlim([0.01,1])
ax2.plot(x_CNT_3_nm_Vd_1p5_dr, y_CNT_3_nm_Vd_1p5_dr, 'o', ms = 7, color='forestgreen', linestyle='-',
         mew = 0.5, mec = 'black',linewidth=2, label = '$I_D$')
ax2.plot(x_CNT_3_nm_Vd_1p5_lk, y_CNT_3_nm_Vd_1p5_lk, 'o', ms = 7, color='tomato', linestyle='-',
         mew = 0.5, mec = 'black',linewidth=2, label = 'Gate Leakage')
#ax2.fill_between(x_CNT_2_nm_Vd_1_lk[0:121],y_CNT_2_nm_Vd_1_dr[0:121],y_CNT_2_nm_Vd_1_lk[0:121], color = 'steelblue')

ax3 = fig.add_subplot(223)

ax3.set_xlabel('V$_g$ [V]', fontsize = 15)
ax3.set_ylabel('Current [A]', fontsize = 15)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
ax3.set_facecolor('#f2f7ff')

xticks = [0, 0.5, 1, 1.5, 2]
ax3.set_title("CNT diameter = 3 nm; $V_D$ = 2 V\n", fontsize = 14)
#axes.grid('off')
#axes.set_yticks(axes.get_yticks()[::1])
ax3.set_xticks(xticks)
#ax3.set_ylim([1e-12, 1e-8])
#ax3.text(0.8, 2.5e-9, "CNT diameter = 2 nm\n\n     $V_D$ = 1 V", fontsize = 14)
#ax3.set_yscale('log')
ax3.set_xlim([0.02,2])
ax3.plot(x_CNT_3_nm_Vd_2_dr, y_CNT_3_nm_Vd_2_dr, 'o', ms = 7, color='forestgreen', linestyle='-',
         mew = 0.5, mec = 'black',linewidth=2, label = '$I_D$')
ax3.plot(x_CNT_3_nm_Vd_2_lk, y_CNT_3_nm_Vd_2_lk, 'o', ms = 7, color='tomato', linestyle='-',
         mew = 0.5, mec = 'black',linewidth=2, label = 'Gate Leakage')
#ax3.fill_between(x_CNT_2_nm_Vd_1_lk[0:121],y_CNT_2_nm_Vd_1_dr[0:121],y_CNT_2_nm_Vd_1_lk[0:121], color = 'steelblue')

ax4 = fig.add_subplot(224)

ax4.set_xlabel('V$_g$ [V]', fontsize = 15)
ax4.set_ylabel('Current [A]', fontsize = 15)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
ax4.set_facecolor('#f2f7ff')

xticks = [0, 0.5, 1, 1.5, 2]
ax4.set_title("CNT diameter = 3 nm; $V_D$ = 2.5 V\n", fontsize = 14)
#axes.grid('off')
#axes.set_yticks(axes.get_yticks()[::1])
ax4.set_xticks(xticks)
#ax4.set_ylim([1e-12, 1e-8])
#ax4.text(0.8, 2.5e-9, "CNT diameter = 2 nm\n\n     $V_D$ = 1 V", fontsize = 14)
#ax4.set_yscale('log')
ax4.set_xlim([0.02,2])
ax4.plot(x_CNT_3_nm_Vd_2p5_dr, y_CNT_3_nm_Vd_2p5_dr, 'o', ms = 7, color='forestgreen', linestyle='-',
         mew = 0.5, mec = 'black',linewidth=2, label = '$I_D$')
ax4.plot(x_CNT_3_nm_Vd_2p5_lk, y_CNT_3_nm_Vd_2p5_lk, 'o', ms = 7, color='tomato', linestyle='-',
         mew = 0.5, mec = 'black',linewidth=2, label = 'Gate Leakage')
#ax4.fill_between(x_CNT_2_nm_Vd_1_lk[0:121],y_CNT_2_nm_Vd_1_dr[0:121],y_CNT_2_nm_Vd_1_lk[0:121], color = 'steelblue')

ax1.legend(loc='best',ncol=1, fontsize = 12)
#ax2.legend(loc='best',ncol=1, fontsize = 12)
#ax3.legend(loc='best',ncol=1, fontsize = 12)
#ax4.legend(loc='best',ncol=1, fontsize = 12)

plt.tight_layout()
plt.savefig("CNT_radii/3_nm/3_nm_Vd_grid.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(10,10))

ax1 = fig.add_subplot(221)

ax1.set_xlabel('V$_g$ [V]', fontsize = 15)
ax1.set_ylabel('Current [A]', fontsize = 15)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
ax1.set_facecolor('#f2f7ff')

xticks = [0, 0.5, 1, 1.5, 2]
ax1.set_title("CNT diameter = 4 nm; $V_D$ = 1.0 V\n", fontsize = 14)
#axes.grid('off')
#axes.set_yticks(axes.get_yticks()[::1])
ax1.set_xticks(xticks)
#ax1.set_ylim([1e-12, 1e-8])
#ax1.text(0.8, 2.5e-9, "CNT diameter = 2 nm\n\n     $V_D$ = 1 V", fontsize = 14)
#ax1.set_yscale('log')
#ax1.set_xlim([0.01,1])
ax1.plot(x_CNT_4_nm_Vd_1_dr, y_CNT_4_nm_Vd_1_dr, 'o', ms = 7, color='forestgreen', linestyle='-',
         mew = 0.5, mec = 'black',linewidth=2, label = '$I_D$')
ax1.plot(x_CNT_4_nm_Vd_1_lk, y_CNT_4_nm_Vd_1_lk, 'o', ms = 7, color='tomato', linestyle='-',
         mew = 0.5, mec = 'black',linewidth=2, label = 'Gate Leakage')
#ax1.fill_between(x_CNT_2_nm_Vd_1_lk[0:121],y_CNT_2_nm_Vd_1_dr[0:121],y_CNT_2_nm_Vd_1_lk[0:121], color = 'steelblue')


ax2 = fig.add_subplot(222)

ax2.set_xlabel('V$_g$ [V]', fontsize = 15)
ax2.set_ylabel('Current [A]', fontsize = 15)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
ax2.set_facecolor('#f2f7ff')

xticks = [0, 0.5, 1, 1.5, 2]
ax2.set_title("CNT diameter = 4 nm; $V_D$ = 1.5 V\n", fontsize = 14)
#axes.grid('off')
#axes.set_yticks(axes.get_yticks()[::1])
ax2.set_xticks(xticks)
#ax2.set_ylim([1e-12, 1e-8])
#ax2.text(0.8, 2.5e-9, "CNT diameter = 2 nm\n\n     $V_D$ = 1 V", fontsize = 14)
#ax2.set_yscale('log')
#ax2.set_xlim([0.01,1])
ax2.plot(x_CNT_4_nm_Vd_1p5_dr, y_CNT_4_nm_Vd_1p5_dr, 'o', ms = 7, color='forestgreen', linestyle='-',
         mew = 0.5, mec = 'black',linewidth=2, label = '$I_D$')
ax2.plot(x_CNT_4_nm_Vd_1p5_lk, y_CNT_4_nm_Vd_1p5_lk, 'o', ms = 7, color='tomato', linestyle='-',
         mew = 0.5, mec = 'black',linewidth=2, label = 'Gate Leakage')
#ax2.fill_between(x_CNT_2_nm_Vd_1_lk[0:121],y_CNT_2_nm_Vd_1_dr[0:121],y_CNT_2_nm_Vd_1_lk[0:121], color = 'steelblue')

ax3 = fig.add_subplot(223)

ax3.set_xlabel('V$_g$ [V]', fontsize = 15)
ax3.set_ylabel('Current [A]', fontsize = 15)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
ax3.set_facecolor('#f2f7ff')

xticks = [0, 0.5, 1, 1.5, 2]
ax3.set_title("CNT diameter = 4 nm; $V_D$ = 2 V\n", fontsize = 14)
#axes.grid('off')
#axes.set_yticks(axes.get_yticks()[::1])
ax3.set_xticks(xticks)
#ax3.set_ylim([1e-12, 1e-8])
#ax3.text(0.8, 2.5e-9, "CNT diameter = 2 nm\n\n     $V_D$ = 1 V", fontsize = 14)
#ax3.set_yscale('log')
ax3.set_xlim([0.02,2])
ax3.plot(x_CNT_4_nm_Vd_2_dr, y_CNT_4_nm_Vd_2_dr, 'o', ms = 7, color='forestgreen', linestyle='-',
         mew = 0.5, mec = 'black',linewidth=2, label = '$I_D$')
ax3.plot(x_CNT_4_nm_Vd_2_lk, y_CNT_4_nm_Vd_2_lk, 'o', ms = 7, color='tomato', linestyle='-',
         mew = 0.5, mec = 'black',linewidth=2, label = 'Gate Leakage')
#ax3.fill_between(x_CNT_2_nm_Vd_1_lk[0:121],y_CNT_2_nm_Vd_1_dr[0:121],y_CNT_2_nm_Vd_1_lk[0:121], color = 'steelblue')

ax4 = fig.add_subplot(224)

ax4.set_xlabel('V$_g$ [V]', fontsize = 15)
ax4.set_ylabel('Current [A]', fontsize = 15)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
ax4.set_facecolor('#f2f7ff')

xticks = [0, 0.5, 1, 1.5, 2]
ax4.set_title("CNT diameter = 4 nm; $V_D$ = 2.5 V\n", fontsize = 14)
#axes.grid('off')
#axes.set_yticks(axes.get_yticks()[::1])
ax4.set_xticks(xticks)
#ax4.set_ylim([1e-12, 1e-8])
#ax4.text(0.8, 2.5e-9, "CNT diameter = 2 nm\n\n     $V_D$ = 1 V", fontsize = 14)
#ax4.set_yscale('log')
ax4.set_xlim([0.02,2])
ax4.plot(x_CNT_4_nm_Vd_2p5_dr, y_CNT_4_nm_Vd_2p5_dr, 'o', ms = 7, color='forestgreen', linestyle='-',
         mew = 0.5, mec = 'black',linewidth=2, label = '$I_D$')
ax4.plot(x_CNT_4_nm_Vd_2p5_lk, y_CNT_4_nm_Vd_2p5_lk, 'o', ms = 7, color='tomato', linestyle='-',
         mew = 0.5, mec = 'black',linewidth=2, label = 'Gate Leakage')
#ax4.fill_between(x_CNT_2_nm_Vd_1_lk[0:121],y_CNT_2_nm_Vd_1_dr[0:121],y_CNT_2_nm_Vd_1_lk[0:121], color = 'steelblue')

ax1.legend(loc='best',ncol=1, fontsize = 12)
#ax2.legend(loc='best',ncol=1, fontsize = 12)
#ax3.legend(loc='best',ncol=1, fontsize = 12)
#ax4.legend(loc='best',ncol=1, fontsize = 12)

plt.tight_layout()
plt.savefig("CNT_radii/4_nm/4_nm_Vd_grid.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(10,10))

ax1 = fig.add_subplot(221)

ax1.set_xlabel('V$_g$ [V]', fontsize = 15)
ax1.set_ylabel('Current [A]', fontsize = 15)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
ax1.set_facecolor('#f2f7ff')

xticks = [0, 0.5, 1, 1.5, 2]
ax1.set_title("CNT diameter = 5 nm; $V_D$ = 1.0 V\n", fontsize = 14)
#axes.grid('off')
#axes.set_yticks(axes.get_yticks()[::1])
ax1.set_xticks(xticks)
#ax1.set_ylim([1e-12, 1e-8])
#ax1.text(0.8, 2.5e-9, "CNT diameter = 2 nm\n\n     $V_D$ = 1 V", fontsize = 14)
#ax1.set_yscale('log')
#ax1.set_xlim([0.01,1])
ax1.plot(x_CNT_5_nm_Vd_1_dr, y_CNT_5_nm_Vd_1_dr, 'o', ms = 7, color='forestgreen', linestyle='-',
         mew = 0.5, mec = 'black',linewidth=2, label = '$I_D$')
ax1.plot(x_CNT_5_nm_Vd_1_lk, y_CNT_5_nm_Vd_1_lk, 'o', ms = 7, color='tomato', linestyle='-',
         mew = 0.5, mec = 'black',linewidth=2, label = 'Gate Leakage')
#ax1.fill_between(x_CNT_2_nm_Vd_1_lk[0:121],y_CNT_2_nm_Vd_1_dr[0:121],y_CNT_2_nm_Vd_1_lk[0:121], color = 'steelblue')


ax2 = fig.add_subplot(222)

ax2.set_xlabel('V$_g$ [V]', fontsize = 15)
ax2.set_ylabel('Current [A]', fontsize = 15)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
ax2.set_facecolor('#f2f7ff')

xticks = [0, 0.5, 1, 1.5, 2]
ax2.set_title("CNT diameter = 5 nm; $V_D$ = 1.5 V\n", fontsize = 14)
#axes.grid('off')
#axes.set_yticks(axes.get_yticks()[::1])
ax2.set_xticks(xticks)
#ax2.set_ylim([1e-12, 1e-8])
#ax2.text(0.8, 2.5e-9, "CNT diameter = 2 nm\n\n     $V_D$ = 1 V", fontsize = 14)
#ax2.set_yscale('log')
#ax2.set_xlim([0.01,1])
ax2.plot(x_CNT_5_nm_Vd_1p5_dr, y_CNT_5_nm_Vd_1p5_dr, 'o', ms = 7, color='forestgreen', linestyle='-',
         mew = 0.5, mec = 'black',linewidth=2, label = '$I_D$')
ax2.plot(x_CNT_5_nm_Vd_1p5_lk, y_CNT_5_nm_Vd_1p5_lk, 'o', ms = 7, color='tomato', linestyle='-',
         mew = 0.5, mec = 'black',linewidth=2, label = 'Gate Leakage')
#ax2.fill_between(x_CNT_2_nm_Vd_1_lk[0:121],y_CNT_2_nm_Vd_1_dr[0:121],y_CNT_2_nm_Vd_1_lk[0:121], color = 'steelblue')

ax3 = fig.add_subplot(223)

ax3.set_xlabel('V$_g$ [V]', fontsize = 15)
ax3.set_ylabel('Current [A]', fontsize = 15)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
ax3.set_facecolor('#f2f7ff')

xticks = [0, 0.5, 1, 1.5, 2]
ax3.set_title("CNT diameter = 5 nm; $V_D$ = 2 V\n", fontsize = 14)
#axes.grid('off')
#axes.set_yticks(axes.get_yticks()[::1])
ax3.set_xticks(xticks)
#ax3.set_ylim([1e-12, 1e-8])
#ax3.text(0.8, 2.5e-9, "CNT diameter = 2 nm\n\n     $V_D$ = 1 V", fontsize = 14)
#ax3.set_yscale('log')
ax3.set_xlim([0.02,2])
ax3.plot(x_CNT_5_nm_Vd_2_dr, y_CNT_5_nm_Vd_2_dr, 'o', ms = 7, color='forestgreen', linestyle='-',
         mew = 0.5, mec = 'black',linewidth=2, label = '$I_D$')
ax3.plot(x_CNT_5_nm_Vd_2_lk, y_CNT_5_nm_Vd_2_lk, 'o', ms = 7, color='tomato', linestyle='-',
         mew = 0.5, mec = 'black',linewidth=2, label = 'Gate Leakage')
#ax3.fill_between(x_CNT_2_nm_Vd_1_lk[0:121],y_CNT_2_nm_Vd_1_dr[0:121],y_CNT_2_nm_Vd_1_lk[0:121], color = 'steelblue')

ax4 = fig.add_subplot(224)

ax4.set_xlabel('V$_g$ [V]', fontsize = 15)
ax4.set_ylabel('Current [A]', fontsize = 15)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
ax4.set_facecolor('#f2f7ff')

xticks = [0, 0.5, 1, 1.5, 2]
ax4.set_title("CNT diameter = 5 nm; $V_D$ = 2.5 V\n", fontsize = 14)
#axes.grid('off')
#axes.set_yticks(axes.get_yticks()[::1])
ax4.set_xticks(xticks)
#ax4.set_ylim([1e-12, 1e-8])
#ax4.text(0.8, 2.5e-9, "CNT diameter = 2 nm\n\n     $V_D$ = 1 V", fontsize = 14)
#ax4.set_yscale('log')
ax4.set_xlim([0.02,2])
ax4.plot(x_CNT_5_nm_Vd_2p5_dr, y_CNT_5_nm_Vd_2p5_dr, 'o', ms = 7, color='forestgreen', linestyle='-',
         mew = 0.5, mec = 'black',linewidth=2, label = '$I_D$')
ax4.plot(x_CNT_5_nm_Vd_2p5_lk, y_CNT_5_nm_Vd_2p5_lk, 'o', ms = 7, color='tomato', linestyle='-',
         mew = 0.5, mec = 'black',linewidth=2, label = 'Gate Leakage')
#ax4.fill_between(x_CNT_2_nm_Vd_1_lk[0:121],y_CNT_2_nm_Vd_1_dr[0:121],y_CNT_2_nm_Vd_1_lk[0:121], color = 'steelblue')

ax1.legend(loc='best',ncol=1, fontsize = 12)
#ax2.legend(loc='best',ncol=1, fontsize = 12)
#ax3.legend(loc='best',ncol=1, fontsize = 12)
#ax4.legend(loc='best',ncol=1, fontsize = 12)

plt.tight_layout()
plt.savefig("CNT_radii/5_nm/5_nm_Vd_grid.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(10,10))

ax1 = fig.add_subplot(221)

ax1.set_xlabel('V$_g$ [V]', fontsize = 15)
ax1.set_ylabel('Current [A]', fontsize = 15)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
ax1.set_facecolor('#f2f7ff')

xticks = [0, 0.5, 1, 1.5, 2]
ax1.set_title("CNT diameter = 10 nm; $V_D$ = 1.0 V\n", fontsize = 14)
#axes.grid('off')
#axes.set_yticks(axes.get_yticks()[::1])
ax1.set_xticks(xticks)
#ax1.set_ylim([1e-12, 1e-8])
#ax1.text(0.8, 2.5e-9, "CNT diameter = 2 nm\n\n     $V_D$ = 1 V", fontsize = 14)
#ax1.set_yscale('log')
#ax1.set_xlim([0.01,1])
ax1.plot(x_CNT_10_nm_Vd_1_dr, y_CNT_10_nm_Vd_1_dr, 'o', ms = 7, color='forestgreen', linestyle='-',
         mew = 0.5, mec = 'black',linewidth=2, label = '$I_D$')
ax1.plot(x_CNT_10_nm_Vd_1_lk, y_CNT_10_nm_Vd_1_lk, 'o', ms = 7, color='tomato', linestyle='-',
         mew = 0.5, mec = 'black',linewidth=2, label = 'Gate Leakage')
#ax1.fill_between(x_CNT_2_nm_Vd_1_lk[0:121],y_CNT_2_nm_Vd_1_dr[0:121],y_CNT_2_nm_Vd_1_lk[0:121], color = 'steelblue')


ax2 = fig.add_subplot(222)

ax2.set_xlabel('V$_g$ [V]', fontsize = 15)
ax2.set_ylabel('Current [A]', fontsize = 15)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
ax2.set_facecolor('#f2f7ff')

xticks = [0, 0.5, 1, 1.5, 2]
ax2.set_title("CNT diameter = 10 nm; $V_D$ = 1.5 V\n", fontsize = 14)
#axes.grid('off')
#axes.set_yticks(axes.get_yticks()[::1])
ax2.set_xticks(xticks)
#ax2.set_ylim([1e-12, 1e-8])
#ax2.text(0.8, 2.5e-9, "CNT diameter = 2 nm\n\n     $V_D$ = 1 V", fontsize = 14)
#ax2.set_yscale('log')
#ax2.set_xlim([0.01,1])
ax2.plot(x_CNT_10_nm_Vd_1p5_dr, y_CNT_10_nm_Vd_1p5_dr, 'o', ms = 7, color='forestgreen', linestyle='-',
         mew = 0.5, mec = 'black',linewidth=2, label = '$I_D$')
ax2.plot(x_CNT_10_nm_Vd_1p5_lk, y_CNT_10_nm_Vd_1p5_lk, 'o', ms = 7, color='tomato', linestyle='-',
         mew = 0.5, mec = 'black',linewidth=2, label = 'Gate Leakage')
#ax2.fill_between(x_CNT_2_nm_Vd_1_lk[0:121],y_CNT_2_nm_Vd_1_dr[0:121],y_CNT_2_nm_Vd_1_lk[0:121], color = 'steelblue')

ax3 = fig.add_subplot(223)

ax3.set_xlabel('V$_g$ [V]', fontsize = 15)
ax3.set_ylabel('Current [A]', fontsize = 15)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
ax3.set_facecolor('#f2f7ff')

xticks = [0, 0.5, 1, 1.5, 2]
ax3.set_title("CNT diameter = 10 nm; $V_D$ = 2 V\n", fontsize = 14)
#axes.grid('off')
#axes.set_yticks(axes.get_yticks()[::1])
ax3.set_xticks(xticks)
#ax3.set_ylim([1e-12, 1e-8])
#ax3.text(0.8, 2.5e-9, "CNT diameter = 2 nm\n\n     $V_D$ = 1 V", fontsize = 14)
#ax3.set_yscale('log')
ax3.set_xlim([0.02,2])
ax3.plot(x_CNT_10_nm_Vd_2_dr, y_CNT_10_nm_Vd_2_dr, 'o', ms = 7, color='forestgreen', linestyle='-',
         mew = 0.5, mec = 'black',linewidth=2, label = '$I_D$')
ax3.plot(x_CNT_10_nm_Vd_2_lk, y_CNT_10_nm_Vd_2_lk, 'o', ms = 7, color='tomato', linestyle='-',
         mew = 0.5, mec = 'black',linewidth=2, label = 'Gate Leakage')
#ax3.fill_between(x_CNT_2_nm_Vd_1_lk[0:121],y_CNT_2_nm_Vd_1_dr[0:121],y_CNT_2_nm_Vd_1_lk[0:121], color = 'steelblue')

ax4 = fig.add_subplot(224)

ax4.set_xlabel('V$_g$ [V]', fontsize = 15)
ax4.set_ylabel('Current [A]', fontsize = 15)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
ax4.set_facecolor('#f2f7ff')

xticks = [0, 0.5, 1, 1.5, 2]
ax4.set_title("CNT diameter = 10 nm; $V_D$ = 2.5 V\n", fontsize = 14)
#axes.grid('off')
#axes.set_yticks(axes.get_yticks()[::1])
ax4.set_xticks(xticks)
#ax4.set_ylim([1e-12, 1e-8])
#ax4.text(0.8, 2.5e-9, "CNT diameter = 2 nm\n\n     $V_D$ = 1 V", fontsize = 14)
#ax4.set_yscale('log')
ax4.set_xlim([0.02,2])
ax4.plot(x_CNT_10_nm_Vd_2p5_dr, y_CNT_10_nm_Vd_2p5_dr, 'o', ms = 7, color='forestgreen', linestyle='-',
         mew = 0.5, mec = 'black',linewidth=2, label = '$I_D$')
ax4.plot(x_CNT_10_nm_Vd_2p5_lk, y_CNT_10_nm_Vd_2p5_lk, 'o', ms = 7, color='tomato', linestyle='-',
         mew = 0.5, mec = 'black',linewidth=2, label = 'Gate Leakage')
#ax4.fill_between(x_CNT_2_nm_Vd_1_lk[0:121],y_CNT_2_nm_Vd_1_dr[0:121],y_CNT_2_nm_Vd_1_lk[0:121], color = 'steelblue')

ax1.legend(loc='best',ncol=1, fontsize = 12)
#ax2.legend(loc='best',ncol=1, fontsize = 12)
#ax3.legend(loc='best',ncol=1, fontsize = 12)
#ax4.legend(loc='best',ncol=1, fontsize = 12)

plt.tight_layout()
plt.savefig("CNT_radii/10_nm/10_nm_Vd_grid.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(10,10))

ax1 = fig.add_subplot(221)

ax1.set_xlabel('V$_g$ [V]', fontsize = 15)
ax1.set_ylabel('$I_D$ [A]', fontsize = 15)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
ax1.set_facecolor('#f2f7ff')
#from matplotlib import ticker
#formatter = ticker.ScalarFormatter(useMathText=True)
#formatter.set_scientific(True)
#formatter.set_powerlimits((-1,1))
#axes.yaxis.set_major_formatter(formatter)


xticks = [0, 0.5, 1, 1.5, 2]
ax1.set_title("CNT diameter = 2 nm", fontsize = 14)
#axes.grid('off')
#axes.set_yticks(axes.get_yticks()[::1])
ax1.set_xticks(xticks)
#ax1.set_ylim([5e-11, 5e-9])
#ax1.text(0.8, 2.5e-9, "CNT diameter = 2 nm\n\n     $V_D$ = 1 V", fontsize = 14)
#ax1.set_yscale('log')
ax1.set_xlim([0.01,1])
ax1.plot(x_CNT_2_nm_Vd_1_dr, y_CNT_2_nm_Vd_1_dr, 'o', ms = 7, color='forestgreen', linestyle='-',
         mew = 0.5, mec = 'black',linewidth=2, label = '$V_D$ = 1 V')
ax1.plot(x_CNT_2_nm_Vd_1p5_dr, y_CNT_2_nm_Vd_1p5_dr, 'o', ms = 7, color='blue', linestyle='-',
         mew = 0.5, mec = 'black',linewidth=2, label = '$V_D$ = 1.5 V')
ax1.plot(x_CNT_2_nm_Vd_2_dr, y_CNT_2_nm_Vd_2_dr, 'o', ms = 7, color='red', linestyle='-',
         mew = 0.5, mec = 'black',linewidth=2, label = '$V_D$ = 2 V')
ax1.plot(x_CNT_2_nm_Vd_2p5_dr, y_CNT_2_nm_Vd_2p5_dr, 'o', ms = 7, color='gold', linestyle='-',
         mew = 0.5, mec = 'black',linewidth=2, label = '$V_D$ = 2.5 V')
#ax1.fill_between(x_CNT_2_nm_Vd_1_lk[0:121],y_CNT_2_nm_Vd_1_dr[0:121],y_CNT_2_nm_Vd_1_lk[0:121], color = 'steelblue')

ax1.legend(loc='best',ncol=1, fontsize = 12)

ax2 = fig.add_subplot(222)

ax2.set_xlabel('V$_g$ [V]', fontsize = 15)
ax2.set_ylabel('$I_D$ [A]', fontsize = 15)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
ax2.set_facecolor('#f2f7ff')
#from matplotlib import ticker
#formatter = ticker.ScalarFormatter(useMathText=True)
#formatter.set_scientific(True)
#formatter.set_powerlimits((-1,1))
#axes.yaxis.set_major_formatter(formatter)

ax2.set_title("CNT diameter = 3 nm", fontsize = 14)
#axes.grid('off')
#axes.set_yticks(axes.get_yticks()[::1])
ax2.set_xticks(xticks)
#ax2.set_ylim([5e-11, 5e-9])
#ax2.text(0.8, 2.5e-9, "CNT diameter = 2 nm\n\n     $V_D$ = 1 V", fontsize = 14)
#ax2.set_yscale('log')
ax2.set_xlim([0.01,1])
ax2.plot(x_CNT_3_nm_Vd_1_dr, y_CNT_3_nm_Vd_1_dr, 'o', ms = 7, color='forestgreen', linestyle='-',
         mew = 0.5, mec = 'black',linewidth=2, label = '$V_D$ = 1 V')
ax2.plot(x_CNT_3_nm_Vd_1p5_dr, y_CNT_3_nm_Vd_1p5_dr, 'o', ms = 7, color='blue', linestyle='-',
         mew = 0.5, mec = 'black',linewidth=2, label = '$V_D$ = 1.5 V')
ax2.plot(x_CNT_3_nm_Vd_2_dr, y_CNT_3_nm_Vd_2_dr, 'o', ms = 7, color='red', linestyle='-',
         mew = 0.5, mec = 'black',linewidth=2, label = '$V_D$ = 2 V')
ax2.plot(x_CNT_3_nm_Vd_2p5_dr, y_CNT_3_nm_Vd_2p5_dr, 'o', ms = 7, color='gold', linestyle='-',
         mew = 0.5, mec = 'black',linewidth=2, label = '$V_D$ = 2.5 V')
#ax2.fill_between(x_CNT_2_nm_Vd_1_lk[0:121],y_CNT_2_nm_Vd_1_dr[0:121],y_CNT_2_nm_Vd_1_lk[0:121], color = 'steelblue')

ax2.legend(loc='best',ncol=1, fontsize = 12)

ax3 = fig.add_subplot(223)

ax3.set_xlabel('V$_g$ [V]', fontsize = 15)
ax3.set_ylabel('$I_D$ [A]', fontsize = 15)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
ax3.set_facecolor('#f2f7ff')
#from matplotlib import ticker
#formatter = ticker.ScalarFormatter(useMathText=True)
#formatter.set_scientific(True)
#formatter.set_powerlimits((-1,1))
#axes.yaxis.set_major_formatter(formatter)

ax3.set_title("CNT diameter = 4 nm", fontsize = 14)
#axes.grid('off')
#axes.set_yticks(axes.get_yticks()[::1])
ax3.set_xticks(xticks)
#ax3.set_ylim([5e-11, 5e-9])
#ax3.text(0.8, 2.5e-9, "CNT diameter = 2 nm\n\n     $V_D$ = 1 V", fontsize = 14)
#ax3.set_yscale('log')
ax3.set_xlim([0.01,1])
ax3.plot(x_CNT_4_nm_Vd_1_dr, y_CNT_4_nm_Vd_1_dr, 'o', ms = 7, color='forestgreen', linestyle='-',
         mew = 0.5, mec = 'black',linewidth=2, label = '$V_D$ = 1 V')
ax3.plot(x_CNT_4_nm_Vd_1p5_dr, y_CNT_4_nm_Vd_1p5_dr, 'o', ms = 7, color='blue', linestyle='-',
         mew = 0.5, mec = 'black',linewidth=2, label = '$V_D$ = 1.5 V')
ax3.plot(x_CNT_4_nm_Vd_2_dr, y_CNT_4_nm_Vd_2_dr, 'o', ms = 7, color='red', linestyle='-',
         mew = 0.5, mec = 'black',linewidth=2, label = '$V_D$ = 2 V')
ax3.plot(x_CNT_4_nm_Vd_2p5_dr, y_CNT_4_nm_Vd_2p5_dr, 'o', ms = 7, color='gold', linestyle='-',
         mew = 0.5, mec = 'black',linewidth=2, label = '$V_D$ = 2.5 V')
#ax3.fill_between(x_CNT_2_nm_Vd_1_lk[0:121],y_CNT_2_nm_Vd_1_dr[0:121],y_CNT_2_nm_Vd_1_lk[0:121], color = 'steelblue')

ax3.legend(loc='best',ncol=1, fontsize = 12)

ax4 = fig.add_subplot(224)

ax4.set_xlabel('V$_g$ [V]', fontsize = 15)
ax4.set_ylabel('$I_D$ [A]', fontsize = 15)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
ax4.set_facecolor('#f2f7ff')
#from matplotlib import ticker
#formatter = ticker.ScalarFormatter(useMathText=True)
#formatter.set_scientific(True)
#formatter.set_powerlimits((-1,1))
#axes.yaxis.set_major_formatter(formatter)

ax4.set_title("CNT diameter = 5 nm", fontsize = 14)
#axes.grid('off')
#axes.set_yticks(axes.get_yticks()[::1])
ax4.set_xticks(xticks)
#ax4.set_ylim([5e-11, 5e-9])
#ax4.text(0.8, 2.5e-9, "CNT diameter = 2 nm\n\n     $V_D$ = 1 V", fontsize = 14)
#ax4.set_yscale('log')
ax4.set_xlim([0.01,1])
ax4.plot(x_CNT_5_nm_Vd_1_dr, y_CNT_5_nm_Vd_1_dr, 'o', ms = 7, color='forestgreen', linestyle='-',
         mew = 0.5, mec = 'black',linewidth=2, label = '$V_D$ = 1 V')
ax4.plot(x_CNT_5_nm_Vd_1p5_dr, y_CNT_5_nm_Vd_1p5_dr, 'o', ms = 7, color='blue', linestyle='-',
         mew = 0.5, mec = 'black',linewidth=2, label = '$V_D$ = 1.5 V')
ax4.plot(x_CNT_5_nm_Vd_2_dr, y_CNT_5_nm_Vd_2_dr, 'o', ms = 7, color='red', linestyle='-',
         mew = 0.5, mec = 'black',linewidth=2, label = '$V_D$ = 2 V')
ax4.plot(x_CNT_5_nm_Vd_2p5_dr, y_CNT_5_nm_Vd_2p5_dr, 'o', ms = 7, color='gold', linestyle='-',
         mew = 0.5, mec = 'black',linewidth=2, label = '$V_D$ = 2.5 V')
#ax4.fill_between(x_CNT_2_nm_Vd_1_lk[0:121],y_CNT_2_nm_Vd_1_dr[0:121],y_CNT_2_nm_Vd_1_lk[0:121], color = 'steelblue')

ax4.legend(loc='best',ncol=1, fontsize = 12)

plt.tight_layout()
plt.savefig("CNT_radii/all_Vd_swings_grid.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(5,5))

ax1 = fig.add_subplot(111)

ax1.set_xlabel('V$_g$ [V]', fontsize = 15)
ax1.set_ylabel('$I_D$ [A]', fontsize = 15)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
ax1.set_facecolor('#f2f7ff')
#from matplotlib import ticker
#formatter = ticker.ScalarFormatter(useMathText=True)
#formatter.set_scientific(True)
#formatter.set_powerlimits((-1,1))
#axes.yaxis.set_major_formatter(formatter)


xticks = [0, 0.5, 1, 1.5, 2]
ax1.set_title("$V_D$ = 1.5 V", fontsize = 14)
#axes.grid('off')
#axes.set_yticks(axes.get_yticks()[::1])
ax1.set_xticks(xticks)
#ax1.set_ylim([5e-11, 5e-9])
#ax1.text(0.8, 2.5e-9, "CNT diameter = 2 nm\n\n     $V_D$ = 1 V", fontsize = 14)
#ax1.set_yscale('log')
ax1.set_xlim([0.01,1])
ax1.plot(x_CNT_2_nm_Vd_1p5_dr, y_CNT_2_nm_Vd_1p5_dr, 'o', ms = 7, color='forestgreen', linestyle='-',
         mew = 0.5, mec = 'black',linewidth=2, label = 'd$_{\mathrm{CNT}}$ = 2 nm')
ax1.plot(x_CNT_3_nm_Vd_1p5_dr, y_CNT_3_nm_Vd_1p5_dr, 'o', ms = 7, color='blue', linestyle='-',
         mew = 0.5, mec = 'black',linewidth=2, label = 'd$_{\mathrm{CNT}}$ = 3 nm')
ax1.plot(x_CNT_4_nm_Vd_1p5_dr, y_CNT_4_nm_Vd_1p5_dr, 'o', ms = 7, color='red', linestyle='-',
         mew = 0.5, mec = 'black',linewidth=2, label = 'd$_{\mathrm{CNT}}$ = 4 nm')
ax1.plot(x_CNT_5_nm_Vd_1p5_dr, y_CNT_5_nm_Vd_1p5_dr, 'o', ms = 7, color='gold', linestyle='-',
         mew = 0.5, mec = 'black',linewidth=2, label = 'd$_{\mathrm{CNT}}$ = 5 nm')
ax1.plot(x_CNT_10_nm_Vd_1p5_dr, y_CNT_10_nm_Vd_1p5_dr, 'o', ms = 7, color='black', linestyle='-',
         mew = 0.5, mec = 'black',linewidth=2, label = 'd$_{\mathrm{CNT}}$ = 10 nm')
#ax1.fill_between(x_CNT_2_nm_Vd_1_lk[0:121],y_CNT_2_nm_Vd_1_dr[0:121],y_CNT_2_nm_Vd_1_lk[0:121], color = 'steelblue')

ax1.text(0.4, 0.4e-9, '10 nm', fontsize = 14)
ax1.text(0.3, 2.3e-9, '5 nm', fontsize = 14, color = 'orange')
ax1.text(0.25, 1.6e-9, '4 nm', fontsize = 14, color = 'red')
ax1.text(0.6, 2.8e-9, '3 nm', fontsize = 14, color = 'blue')
ax1.text(0.8, 2e-9, '2 nm', fontsize = 14, color = 'forestgreen')
#ax1.legend(loc='best',ncol=1, fontsize = 12)

plt.savefig("CNT_radii/all_diameters_at_Vd_1p5.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
a = max(y_CNT_3_nm_Vd_1p5_dr)

# %%
b = y_CNT_3_nm_Vd_1p5_dr[80]

# %%
a/b
# Out:
# 7.802862163937149

# %%
CNT_3_nm_Vd_1p5_em = pd.read_csv("CNT_radii/3_nm/CNT_3_nm_Vd_1p5_electron_mobility.csv")
x_CNT_3_nm_Vd_1p5_em = CNT_3_nm_Vd_1p5_em['eMobility(C1(C2(n320_des))) X']
y_CNT_3_nm_Vd_1p5_em = CNT_3_nm_Vd_1p5_em['eMobility(C1(C2(n320_des))) Y']

CNT_3_nm_Vd_1p5_ev = pd.read_csv("CNT_radii/3_nm/CNT_3_nm_Vd_1p5_electron_velocity.csv")
x_CNT_3_nm_Vd_1p5_ev = CNT_3_nm_Vd_1p5_ev['eVelocity(C1(C2(n320_des))) X']
y_CNT_3_nm_Vd_1p5_ev = CNT_3_nm_Vd_1p5_ev['eVelocity(C1(C2(n320_des))) Y']

CNT_3_nm_Vd_1p5_ep = pd.read_csv("CNT_radii/3_nm/CNT_3_nm_Vd_1p5_electrostatic_potential.csv")
x_CNT_3_nm_Vd_1p5_ep = CNT_3_nm_Vd_1p5_ep['ElectrostaticPotential(C1(C2(n320_des))) X']
y_CNT_3_nm_Vd_1p5_ep = CNT_3_nm_Vd_1p5_ep['ElectrostaticPotential(C1(C2(n320_des))) Y']

CNT_3_nm_Vd_1p5_sc = pd.read_csv("CNT_radii/3_nm/CNT_3_nm_Vd_1p5_space_charge.csv")
x_CNT_3_nm_Vd_1p5_sc = CNT_3_nm_Vd_1p5_sc['SpaceCharge(C1(C2(n320_des))) X']
y_CNT_3_nm_Vd_1p5_sc = CNT_3_nm_Vd_1p5_sc['SpaceCharge(C1(C2(n320_des))) Y']

CNT_3_nm_Vd_1p5_ef = pd.read_csv("CNT_radii/3_nm/CNT_3_nm_Vd_1p5_electric_field.csv")
x_CNT_3_nm_Vd_1p5_ef = CNT_3_nm_Vd_1p5_ef['Abs(ElectricField-V)(C1(C1(n320_des))) X']
y_CNT_3_nm_Vd_1p5_ef = CNT_3_nm_Vd_1p5_ef['Abs(ElectricField-V)(C1(C1(n320_des))) Y']

CNT_3_nm_Vd_1p5_to = pd.read_csv("CNT_radii/3_nm/CNT_3_nm_Vd_1p5_trap_occupation.csv")
x_CNT_3_nm_Vd_1p5_to = CNT_3_nm_Vd_1p5_to['Abs(TrapOccupation_0(eN:Ta)-V)(C1(C2(n320_des))) X']
y_CNT_3_nm_Vd_1p5_to = CNT_3_nm_Vd_1p5_to['Abs(TrapOccupation_0(eN:Ta)-V)(C1(C2(n320_des))) Y']

CNT_3_nm_Vd_1p5_bd = pd.read_csv("CNT_radii/3_nm/CNT_3_nm_Vd_1p5_band_diagram.csv")
Ec_x_CNT_3_nm_Vd_1p5_bd = CNT_3_nm_Vd_1p5_bd['Ec X']
Ec_y_CNT_3_nm_Vd_1p5_bd = CNT_3_nm_Vd_1p5_bd['Ec Y']
Ev_x_CNT_3_nm_Vd_1p5_bd = CNT_3_nm_Vd_1p5_bd['Ev X']
Ev_y_CNT_3_nm_Vd_1p5_bd = CNT_3_nm_Vd_1p5_bd['Ev Y']
Efn_x_CNT_3_nm_Vd_1p5_bd = CNT_3_nm_Vd_1p5_bd['Efn X']
Efn_y_CNT_3_nm_Vd_1p5_bd = CNT_3_nm_Vd_1p5_bd['Efn Y']
Efp_x_CNT_3_nm_Vd_1p5_bd = CNT_3_nm_Vd_1p5_bd['Efp X']
Efp_y_CNT_3_nm_Vd_1p5_bd = CNT_3_nm_Vd_1p5_bd['Efp Y']

# %%
fig = plt.figure(figsize=(15,8))

ax1 = fig.add_subplot(321)

ax1.set_xlabel('$x$ coordinate [nm]', fontsize = 12)
ax1.set_ylabel('Energy [eV]', fontsize = 12)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
#from matplotlib import ticker
#formatter = ticker.ScalarFormatter(useMathText=True)
#formatter.set_scientific(True)
#formatter.set_powerlimits((-1,1))
#axes.yaxis.set_major_formatter(formatter)
#ax1.set_xlim([0.01,3])
#ax1.set_ylim([5e-6, 3e-4])
ax1.grid('off')
#ax1.set_yticks(axes.get_yticks()[::1])
#ax1.set_xticks(axes.get_xticks()[::2])
#ax1.text(0.25, 7.5e-5, "V$_d$ = 3 V\nL$_c$ = 60 nm", fontsize = 14)
#ax1.set_yscale('log')
ax1.plot(Ec_x_CNT_3_nm_Vd_1p5_bd*1000, Ec_y_CNT_3_nm_Vd_1p5_bd, color='forestgreen', linestyle='-', linewidth=3, label = 'E$_c$')
ax1.plot(Ev_x_CNT_3_nm_Vd_1p5_bd*1000, Ev_y_CNT_3_nm_Vd_1p5_bd, color='steelblue', linestyle='-', linewidth=3, label = 'E$_v$')
ax1.plot(Efn_x_CNT_3_nm_Vd_1p5_bd*1000, Efn_y_CNT_3_nm_Vd_1p5_bd, color='olive', linestyle=':', linewidth=3, label = 'E$_{\mathrm{fn}}$')
ax1.plot(Efp_x_CNT_3_nm_Vd_1p5_bd*1000, Efp_y_CNT_3_nm_Vd_1p5_bd, color='midnightblue', linestyle=':', linewidth=3, label = 'E$_{\mathrm{fp}}$')
#ax1.axvline(0.14, color = 'black')
#ax1.axvline(0.15, color = 'black')
ax1.legend(loc='upper right',ncol=2, fontsize = 10)

ax2 = fig.add_subplot(322)

ax2.set_xlabel('$x$ coordinate [nm]', fontsize = 12)
ax2.set_ylabel('$v_e$ [cm s$^{-1}$]', fontsize = 12)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
from matplotlib import ticker
formatter = ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True)
formatter.set_powerlimits((-1,1))
ax2.yaxis.set_major_formatter(formatter)
#ax2.set_xlim([0.01,3])
#ax2.set_ylim([5e-6, 3e-4])
ax2.grid('off')
#ax2.set_yticks(axes.get_yticks()[::1])
#ax2.set_xticks(axes.get_xticks()[::2])
#ax2.text(0.25, 7.5e-5, "V$_d$ = 3 V\nL$_c$ = 60 nm", fontsize = 14)
#ax2.set_yscale('log')

ax2.plot(x_CNT_3_nm_Vd_1p5_ev*1000, y_CNT_3_nm_Vd_1p5_ev, color='steelblue', linestyle='-', linewidth=3, label = '$d_{\mathrm{CNT}}$ = 3 nm')

#ax2.axvline(0.14, color = 'black')
#ax2.axvline(0.15, color = 'black')
ax2.legend(loc='upper left',ncol=4, fontsize = 14)

ax3 = fig.add_subplot(323)

ax3.set_xlabel('$x$ coordinate [nm]', fontsize = 12)
ax3.set_ylabel('$\mu_e$ [cm$^2$ V$^{-1}$ s$^{-1}$]', fontsize = 12)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
#from matplotlib import ticker
#formatter = ticker.ScalarFormatter(useMathText=True)
#formatter.set_scientific(True)
#formatter.set_powerlimits((-1,1))
#axes.yaxis.set_major_formatter(formatter)
#ax3.set_xlim([0.01,3])
#ax3.set_ylim([5e-6, 3e-4])
ax3.grid('off')
#ax3.set_yticks(axes.get_yticks()[::1])
#ax3.set_xticks(axes.get_xticks()[::2])
#ax3.text(0.25, 7.5e-5, "V$_d$ = 3 V\nL$_c$ = 60 nm", fontsize = 14)
#ax3.set_yscale('log')

ax3.plot(x_CNT_3_nm_Vd_1p5_em*1000, y_CNT_3_nm_Vd_1p5_em, color='red', linestyle='-', linewidth=3, label = '$d_{\mathrm{CNT}}$ = 3 nm')

#ax3.axvline(0.14, color = 'black')
#ax3.axvline(0.15, color = 'black')
ax3.legend(loc='upper left',ncol=4, fontsize = 14)

ax4 = fig.add_subplot(324)

ax4.set_xlabel('$x$ coordinate [nm]', fontsize = 12)
ax4.set_ylabel('$\phi$ [V]', fontsize = 12)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
#from matplotlib import ticker
#formatter = ticker.ScalarFormatter(useMathText=True)
#formatter.set_scientific(True)
#formatter.set_powerlimits((-1,1))
#axes.yaxis.set_major_formatter(formatter)
#ax4.set_xlim([0.01,3])
#ax4.set_ylim([5e-6, 3e-4])
ax4.grid('off')
#ax4.set_yticks(axes.get_yticks()[::1])
#ax4.set_xticks(axes.get_xticks()[::2])
#ax4.text(0.25, 7.5e-5, "V$_d$ = 3 V\nL$_c$ = 60 nm", fontsize = 14)
#ax4.set_yscale('log')

ax4.plot(x_CNT_3_nm_Vd_1p5_ep*1000, y_CNT_3_nm_Vd_1p5_ep, color='midnightblue', linestyle='-', linewidth=3, label = '$d_{\mathrm{CNT}}$ = 3 nm')

#ax4.axvline(0.14, color = 'black')
#ax4.axvline(0.15, color = 'black')
ax4.legend(loc='lower right',ncol=4, fontsize = 14)

ax5 = fig.add_subplot(325)

ax5.set_xlabel('$x$ coordinate [nm]', fontsize = 12)
ax5.set_ylabel('Trap Occupation [cm$^{-3}$ eV$^{-1}$]', fontsize = 12)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
#from matplotlib import ticker
#formatter = ticker.ScalarFormatter(useMathText=True)
#formatter.set_scientific(True)
#formatter.set_powerlimits((-1,1))
#axes.yaxis.set_major_formatter(formatter)
#ax5.set_xlim([0.01,3])
#ax5.set_ylim([5e-6, 3e-4])
ax5.grid('off')
#ax5.set_yticks(axes.get_yticks()[::1])
#ax5.set_xticks(axes.get_xticks()[::2])
#ax5.text(0.25, 7.5e-5, "V$_d$ = 3 V\nL$_c$ = 60 nm", fontsize = 14)
#ax5.set_yscale('log')

ax5.plot(x_CNT_3_nm_Vd_1p5_to*1000, y_CNT_3_nm_Vd_1p5_to, color='purple', linestyle='-', linewidth=3, label = '$d_{\mathrm{CNT}}$ = 3 nm')

#ax5.axvline(0.14, color = 'black')
#ax5.axvline(0.15, color = 'black')
ax5.legend(loc='upper right',ncol=4, fontsize = 14)

ax6 = fig.add_subplot(326)

ax6.set_xlabel('$x$ coordinate [nm]', fontsize = 12)
ax6.set_ylabel('Space Charge [cm$^{-3}$]', fontsize = 12)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
#from matplotlib import ticker
#formatter = ticker.ScalarFormatter(useMathText=True)
#formatter.set_scientific(True)
#formatter.set_powerlimits((-1,1))
#axes.yaxis.set_major_formatter(formatter)
#ax5.set_xlim([0.01,3])
#ax5.set_ylim([5e-6, 3e-4])
ax6.grid('off')
#ax5.set_yticks(axes.get_yticks()[::1])
#ax5.set_xticks(axes.get_xticks()[::2])
#ax5.text(0.25, 7.5e-5, "V$_d$ = 3 V\nL$_c$ = 60 nm", fontsize = 14)
#ax5.set_yscale('log')

ax6.plot(x_CNT_3_nm_Vd_1p5_sc*1000, y_CNT_3_nm_Vd_1p5_sc, color='grey', linestyle='-', linewidth=3, label = '$d_{\mathrm{CNT}}$ = 3 nm')

#ax6.axvline(0.14, color = 'black')
#ax6.axvline(0.15, color = 'black')
ax6.legend(loc='upper right',ncol=4, fontsize = 14)

plt.tight_layout()

plt.savefig("CNT_radii/3_nm/visualization_profiles_Vd_1p5.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(5,5))

ax1 = fig.add_subplot(111)

ax1.set_xlabel('V$_g$ [V]', fontsize = 15)
ax1.set_ylabel('$I_D$ [A]', fontsize = 15)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
ax1.set_facecolor('#f2f7ff')
#from matplotlib import ticker
#formatter = ticker.ScalarFormatter(useMathText=True)
#formatter.set_scientific(True)
#formatter.set_powerlimits((-1,1))
#axes.yaxis.set_major_formatter(formatter)


#xticks = [0, 0.5, 1, 1.5, 2]
ax1.set_title("$V_D$ = 1.5 V", fontsize = 14)
#axes.grid('off')
#axes.set_yticks(axes.get_yticks()[::1])
ax1.set_xticks(xticks)
#ax1.set_ylim([5e-11, 5e-9])
#ax1.text(0.8, 2.5e-9, "CNT diameter = 2 nm\n\n     $V_D$ = 1 V", fontsize = 14)
ax1.set_yscale('log')
#ax1.set_xlim([0.01,1])
ax1.plot(x_CNT_3_nm_Vd_1p5_ef, y_CNT_3_nm_Vd_1p5_ef, 'o', ms = 7, color='forestgreen', linestyle='-',
         mew = 0.5, mec = 'black',linewidth=2, label = 'd$_{\mathrm{CNT}}$ = 3 nm')


plt.savefig("CNT_radii/E_Field_Vd_1p5.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
max(y_CNT_3_nm_Vd_1p5_ef)
# Out:
# 3156739.0
