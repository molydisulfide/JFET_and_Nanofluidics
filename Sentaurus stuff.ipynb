# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy as sp
import csv
import matplotlib.patches as mpatches
import pandas as pd
import matplotlib.ticker as mtick
import matplotlib.tri as mtri

# %%
Si_200_nm_gt = pd.read_csv("Si/Si_200_nm_gate.csv")
x_Si_200_nm_gt = Si_200_nm_gt['x']
y_Si_200_nm_gt = Si_200_nm_gt['y']

Si_200_nm_gt_Vd_3 = pd.read_csv("Si/Si_200_nm_gate_Vd_3.csv")
x_Si_200_nm_gt_Vd_3 = Si_200_nm_gt_Vd_3['x']
y_Si_200_nm_gt_Vd_3 = Si_200_nm_gt_Vd_3['y']

Si_10_nm_gt = pd.read_csv("Si/Si_10_nm_gate.csv")
x_Si_10_nm_gt = Si_10_nm_gt['x']
y_Si_10_nm_gt = Si_10_nm_gt['y']

Si_10_nm_gt_Vd_3 = pd.read_csv("Si/Si_10_nm_gate_Vd_3.csv")
x_Si_10_nm_gt_Vd_3 = Si_10_nm_gt_Vd_3['x']
y_Si_10_nm_gt_Vd_3 = Si_10_nm_gt_Vd_3['y']

Si_5_nm_gt = pd.read_csv("Si/Si_5_nm_gate.csv")
x_Si_5_nm_gt = Si_5_nm_gt['x']
y_Si_5_nm_gt = Si_5_nm_gt['y']

Si_5_nm_gt_Vd_3 = pd.read_csv("Si/Si_5_nm_gate_Vd_3.csv")
x_Si_5_nm_gt_Vd_3 = Si_5_nm_gt_Vd_3['x']
y_Si_5_nm_gt_Vd_3 = Si_5_nm_gt_Vd_3['y']

Si_2_nm_gt = pd.read_csv("Si/Si_2_nm_gate.csv")
x_Si_2_nm_gt = Si_2_nm_gt['x']
y_Si_2_nm_gt = Si_2_nm_gt['y']

Si_2_nm_gt_Vd_3 = pd.read_csv("Si/Si_2_nm_gate_Vd_3.csv")
x_Si_2_nm_gt_Vd_3 = Si_2_nm_gt_Vd_3['x']
y_Si_2_nm_gt_Vd_3 = Si_2_nm_gt_Vd_3['y']

Si_2_nm_gt_Vd_3 = pd.read_csv("Si/Si_2_nm_gate_Vd_3.csv")
x_Si_2_nm_gt_Vd_3 = Si_2_nm_gt_Vd_3['x']
y_Si_2_nm_gt_Vd_3 = Si_2_nm_gt_Vd_3['y']


Si_10_nm_gt_ev = pd.read_csv("Si/Si_10_nm_gate_velocity_profile.csv")
x_Si_10_nm_gt_ev = Si_10_nm_gt_ev['eVelocity(C1(n82_des)) X']
y_Si_10_nm_gt_ev = Si_10_nm_gt_ev['eVelocity(C1(n82_des)) Y']

Si_10_nm_gt_bs = pd.read_csv("Si/Si_10_nm_gate_band_structure.csv")
Ec_x_Si_10_nm_gt_bs = Si_10_nm_gt_bs['Ec X']
Ec_y_Si_10_nm_gt_bs = Si_10_nm_gt_bs['Ec Y']
Ev_x_Si_10_nm_gt_bs = Si_10_nm_gt_bs['Ev X']
Ev_y_Si_10_nm_gt_bs = Si_10_nm_gt_bs['Ev Y']
Efn_x_Si_10_nm_gt_bs = Si_10_nm_gt_bs['Efn X']
Efn_y_Si_10_nm_gt_bs = Si_10_nm_gt_bs['Efn Y']
Efp_x_Si_10_nm_gt_bs = Si_10_nm_gt_bs['Efp X']
Efp_y_Si_10_nm_gt_bs = Si_10_nm_gt_bs['Efp Y']

# %%
moly_200_nm_gt = pd.read_csv("moly/moly_200_nm_gate.csv")
x_moly_200_nm_gt = moly_200_nm_gt['x']
y_moly_200_nm_gt = moly_200_nm_gt['y']

moly_200_nm_gt_Vd_3 = pd.read_csv("moly/moly_200_nm_gate_Vd_3.csv")
x_moly_200_nm_gt_Vd_3 = moly_200_nm_gt_Vd_3['x']
y_moly_200_nm_gt_Vd_3 = moly_200_nm_gt_Vd_3['y']

moly_10_nm_gt = pd.read_csv("moly/moly_10_nm_gate.csv")
x_moly_10_nm_gt = moly_10_nm_gt['x']
y_moly_10_nm_gt = moly_10_nm_gt['y']

moly_10_nm_gt_Vd_3 = pd.read_csv("moly/moly_10_nm_gate_Vd_3.csv")
x_moly_10_nm_gt_Vd_3 = moly_10_nm_gt_Vd_3['x']
y_moly_10_nm_gt_Vd_3 = moly_10_nm_gt_Vd_3['y']

moly_5_nm_gt = pd.read_csv("moly/moly_5_nm_gate.csv")
x_moly_5_nm_gt = moly_5_nm_gt['x']
y_moly_5_nm_gt = moly_5_nm_gt['y']

moly_5_nm_gt_Vd_3 = pd.read_csv("moly/moly_5_nm_gate_Vd_3.csv")
x_moly_5_nm_gt_Vd_3 = moly_5_nm_gt_Vd_3['x']
y_moly_5_nm_gt_Vd_3 = moly_5_nm_gt_Vd_3['y']

moly_2_nm_gt = pd.read_csv("moly/moly_2_nm_gate.csv")
x_moly_2_nm_gt = moly_2_nm_gt['x']
y_moly_2_nm_gt = moly_2_nm_gt['y']

moly_2_nm_gt_Vd_3 = pd.read_csv("moly/moly_2_nm_gate_Vd_3.csv")
x_moly_2_nm_gt_Vd_3 = moly_2_nm_gt_Vd_3['x']
y_moly_2_nm_gt_Vd_3 = moly_2_nm_gt_Vd_3['y']

moly_2_nm_gt_Vd_3 = pd.read_csv("moly/moly_2_nm_gate_Vd_3.csv")
x_moly_2_nm_gt_Vd_3 = moly_2_nm_gt_Vd_3['x']
y_moly_2_nm_gt_Vd_3 = moly_2_nm_gt_Vd_3['y']

moly_5_nm_gt_ev = pd.read_csv("moly/moly_5_nm_gate_electron_velocity.csv")
x_moly_5_nm_gt_ev = moly_5_nm_gt_ev['eVelocity(C1(n73_des)) X']
y_moly_5_nm_gt_ev = moly_5_nm_gt_ev['eVelocity(C1(n73_des)) Y']

moly_5_nm_gt_em = pd.read_csv("moly/moly_5_nm_gate_electron_mobility.csv")
x_moly_5_nm_gt_em = moly_5_nm_gt_em['eMobility(C1(n73_des)) X']
y_moly_5_nm_gt_em = moly_5_nm_gt_em['eMobility(C1(n73_des)) Y']

moly_5_nm_gt_ep = pd.read_csv("moly/moly_5_nm_gate_electrostatic_potential.csv")
x_moly_5_nm_gt_ep = moly_5_nm_gt_ep['ElectrostaticPotential(C1(n73_des)) X']
y_moly_5_nm_gt_ep = moly_5_nm_gt_ep['ElectrostaticPotential(C1(n73_des)) Y']

moly_5_nm_gt_ev = pd.read_csv("moly/moly_5_nm_gate_electron_velocity.csv")
x_moly_5_nm_gt_ev = moly_5_nm_gt_ev['eVelocity(C1(n73_des)) X']
y_moly_5_nm_gt_ev = moly_5_nm_gt_ev['eVelocity(C1(n73_des)) Y']

moly_5_nm_gt_to = pd.read_csv("moly/moly_5_nm_gate_trap_occupation.csv")
x_moly_5_nm_gt_to = moly_5_nm_gt_to['Abs(TrapOccupation_0(eN:Ta)-V)(C1(n73_des)) X']
y_moly_5_nm_gt_to = moly_5_nm_gt_to['Abs(TrapOccupation_0(eN:Ta)-V)(C1(n73_des)) Y']

moly_5_nm_gt_bs = pd.read_csv("moly/moly_5_nm_gate_band_structure.csv")
Ec_x_moly_5_nm_gt_bs = moly_5_nm_gt_bs['Ec X']
Ec_y_moly_5_nm_gt_bs = moly_5_nm_gt_bs['Ec Y']
Ev_x_moly_5_nm_gt_bs = moly_5_nm_gt_bs['Ev X']
Ev_y_moly_5_nm_gt_bs = moly_5_nm_gt_bs['Ev Y']
Efn_x_moly_5_nm_gt_bs = moly_5_nm_gt_bs['Efn X']
Efn_y_moly_5_nm_gt_bs = moly_5_nm_gt_bs['Efn Y']
Efp_x_moly_5_nm_gt_bs = moly_5_nm_gt_bs['Efp X']
Efp_y_moly_5_nm_gt_bs = moly_5_nm_gt_bs['Efp Y']

# %%
fig = plt.figure(figsize=(10.5,5))

ax1 = fig.add_subplot(121)

ax1.set_xlabel('V$_g$ [V]', fontsize = 15)
ax1.set_ylabel('I$_d$ [A]', fontsize = 15)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
#from matplotlib import ticker
#formatter = ticker.ScalarFormatter(useMathText=True)
#formatter.set_scientific(True)
#formatter.set_powerlimits((-1,1))
#axes.yaxis.set_major_formatter(formatter)
ax1.set_xlim([0.01,3])
#ax1.set_ylim([1e-7, 4e-5])
#axes.grid('off')
#axes.set_yticks(axes.get_yticks()[::1])
#axes.set_xticks(axes.get_xticks()[::2])
ax1.text(1.25, 1.5e-6, "V$_d$ = 0.1 V\nL$_c$ = L$_g$ + 100 nm", fontsize = 14)
#axes.set_yscale('log')
ax1.plot(x_moly_2_nm_gt, y_moly_2_nm_gt , color='violet', linestyle='-', linewidth=3, label = 'L$_g$ = 2 nm')
ax1.plot(x_moly_5_nm_gt, y_moly_5_nm_gt , color='dodgerblue', linestyle='-', linewidth=3, label = 'L$_g$ = 5 nm')
ax1.plot(x_moly_10_nm_gt, y_moly_10_nm_gt , color='forestgreen', linestyle='-', linewidth=3, label = 'L$_g$ = 10 nm')
ax1.plot(x_moly_200_nm_gt, y_moly_200_nm_gt , color='black', linestyle='-', linewidth=3, label = 'L$_g$ = 200 nm')

ax1.legend(loc='lower right',ncol=1, fontsize = 14)

ax2 = fig.add_subplot(122)

ax2.set_xlabel('V$_g$ [V]', fontsize = 15)
ax2.set_ylabel('I$_d$ [A]', fontsize = 15)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
#from matplotlib import ticker
#formatter = ticker.ScalarFormatter(useMathText=True)
#formatter.set_scientific(True)
#formatter.set_powerlimits((-1,1))
#axes.yaxis.set_major_formatter(formatter)
ax2.set_xlim([0.01,1.0])
ax2.set_ylim([1e-12, 1e-5])
#axes.grid('off')
#axes.set_yticks(axes.get_yticks()[::1])
#axes.set_xticks(axes.get_xticks()[::2])
ax2.text(0.5, 3e-8, "V$_d$ = 0.1 V\nL$_c$ = L$_g$ + 100 nm", fontsize = 14)
ax2.set_yscale('log')
ax2.plot(x_moly_2_nm_gt, y_moly_2_nm_gt , color='violet', linestyle='-', linewidth=3, label = 'L$_g$ = 2 nm')
ax2.plot(x_moly_5_nm_gt, y_moly_5_nm_gt , color='dodgerblue', linestyle='-', linewidth=3, label = 'L$_g$ = 5 nm')
ax2.plot(x_moly_10_nm_gt, y_moly_10_nm_gt , color='forestgreen', linestyle='-', linewidth=3, label = 'L$_g$ = 10 nm')
ax2.plot(x_moly_200_nm_gt, y_moly_200_nm_gt , color='black', linestyle='-', linewidth=3, label = 'L$_g$ = 200 nm')

ax2.legend(loc='lower right',ncol=1, fontsize = 14)

plt.tight_layout()

plt.savefig("moly/moly_10_nm_gate.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(10.5,5))

ax1 = fig.add_subplot(121)

ax1.set_xlabel('V$_g$ [V]', fontsize = 15)
ax1.set_ylabel('I$_d$ [A]', fontsize = 15)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
#from matplotlib import ticker
#formatter = ticker.ScalarFormatter(useMathText=True)
#formatter.set_scientific(True)
#formatter.set_powerlimits((-1,1))
#axes.yaxis.set_major_formatter(formatter)
ax1.set_xlim([0.01,3])
#ax1.set_ylim([5e-6, 3e-4])
#ax1.grid('off')
#ax1.set_yticks(axes.get_yticks()[::1])
#ax1.set_xticks(axes.get_xticks()[::2])
ax1.text(0.25, 7e-6, "V$_d$ = 3 V\nL$_c$ = L$_g$ + 100 nm", fontsize = 14)
#ax1.set_yscale('log')
ax1.plot(x_moly_2_nm_gt_Vd_3, y_moly_2_nm_gt_Vd_3 , color='violet', linestyle='-', linewidth=3, label = 'L$_g$ = 2 nm')
ax1.plot(x_moly_5_nm_gt_Vd_3, y_moly_5_nm_gt_Vd_3 , color='dodgerblue', linestyle='-', linewidth=3, label = 'L$_g$ = 5 nm')
ax1.plot(x_moly_10_nm_gt_Vd_3, y_moly_10_nm_gt_Vd_3 , color='forestgreen', linestyle='-', linewidth=3, label = 'L$_g$ = 10 nm')
ax1.plot(x_moly_200_nm_gt_Vd_3, y_moly_200_nm_gt_Vd_3 , color='black', linestyle='-', linewidth=3, label = 'L$_g$ = 200 nm')

ax1.legend(loc='lower right',ncol=1, fontsize = 14)

ax2 = fig.add_subplot(122)

ax2.set_xlabel('V$_g$ [V]', fontsize = 15)
ax2.set_ylabel('I$_d$ [A]', fontsize = 15)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
#from matplotlib import ticker
#formatter = ticker.ScalarFormatter(useMathText=True)
#formatter.set_scientific(True)
#formatter.set_powerlimits((-1,1))
#axes.yaxis.set_major_formatter(formatter)
ax2.set_xlim([0.01,3])
ax2.set_ylim([1e-8, 1e-5])
#ax2.grid('off')
#ax2.set_yticks(axes.get_yticks()[::1])
#ax2.set_xticks(axes.get_xticks()[::2])
ax2.text(1.25, 5e-7, "V$_d$ = 3 V\nL$_c$ = L$_g$ + 100 nm", fontsize = 14)
ax2.set_yscale('log')
ax2.plot(x_moly_2_nm_gt_Vd_3, y_moly_2_nm_gt_Vd_3 , color='violet', linestyle='-', linewidth=3, label = 'L$_g$ = 2 nm')
ax2.plot(x_moly_5_nm_gt_Vd_3, y_moly_5_nm_gt_Vd_3 , color='dodgerblue', linestyle='-', linewidth=3, label = 'L$_g$ = 5 nm')
ax2.plot(x_moly_10_nm_gt_Vd_3, y_moly_10_nm_gt_Vd_3 , color='forestgreen', linestyle='-', linewidth=3, label = 'L$_g$ = 10 nm')
ax2.plot(x_moly_200_nm_gt_Vd_3, y_moly_200_nm_gt_Vd_3 , color='black', linestyle='-', linewidth=3, label = 'L$_g$ = 200 nm')

ax2.legend(loc='lower right',ncol=1, fontsize = 14)

plt.tight_layout()

plt.savefig("moly/moly_10_nm_gate_Vd_3.png", dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(10,15))

ax1 = fig.add_subplot(511)

ax1.set_xlabel('$x$ coordinate [$\mu$m]', fontsize = 12)
ax1.set_ylabel('Energy [eV]', fontsize = 12)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
#from matplotlib import ticker
#formatter = ticker.ScalarFormatter(useMathText=True)
#formatter.set_scientific(True)
#formatter.set_powerlimits((-1,1))
#axes.yaxis.set_major_formatter(formatter)
#ax1.set_xlim([0.01,3])
#ax1.set_ylim([5e-6, 3e-4])
ax1.grid('off')
#ax1.set_yticks(axes.get_yticks()[::1])
#ax1.set_xticks(axes.get_xticks()[::2])
#ax1.text(0.25, 7.5e-5, "V$_d$ = 3 V\nL$_c$ = 60 nm", fontsize = 14)
#ax1.set_yscale('log')
ax1.plot(Ec_x_moly_5_nm_gt_bs, Ec_y_moly_5_nm_gt_bs, color='forestgreen', linestyle='-', linewidth=3, label = 'E$_c$')
ax1.plot(Ev_x_moly_5_nm_gt_bs, Ev_y_moly_5_nm_gt_bs, color='steelblue', linestyle='-', linewidth=3, label = 'E$_v$')
ax1.plot(Efn_x_moly_5_nm_gt_bs, Efn_y_moly_5_nm_gt_bs, color='olive', linestyle=':', linewidth=3, label = 'E$_{fn}$')
ax1.plot(Efp_x_moly_5_nm_gt_bs, Efp_y_moly_5_nm_gt_bs, color='midnightblue', linestyle=':', linewidth=3, label = 'E$_{fp}$')
#ax1.axvline(0.14, color = 'black')
#ax1.axvline(0.15, color = 'black')
ax1.legend(loc='center',ncol=4, fontsize = 14)

ax2 = fig.add_subplot(512)

ax2.set_xlabel('$x$ coordinate [$\mu$m]', fontsize = 12)
ax2.set_ylabel('$v_e$ [cm s$^{-1}$]', fontsize = 12)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
#from matplotlib import ticker
#formatter = ticker.ScalarFormatter(useMathText=True)
#formatter.set_scientific(True)
#formatter.set_powerlimits((-1,1))
#axes.yaxis.set_major_formatter(formatter)
#ax2.set_xlim([0.01,3])
#ax2.set_ylim([5e-6, 3e-4])
ax2.grid('off')
#ax2.set_yticks(axes.get_yticks()[::1])
#ax2.set_xticks(axes.get_xticks()[::2])
#ax2.text(0.25, 7.5e-5, "V$_d$ = 3 V\nL$_c$ = 60 nm", fontsize = 14)
#ax2.set_yscale('log')

ax2.plot(x_moly_5_nm_gt_ev, y_moly_5_nm_gt_ev, color='steelblue', linestyle='-', linewidth=3, label = 'L$_g$ = 5 nm')

#ax2.axvline(0.14, color = 'black')
#ax2.axvline(0.15, color = 'black')
ax2.legend(loc='upper right',ncol=4, fontsize = 14)

ax3 = fig.add_subplot(513)

ax3.set_xlabel('$x$ coordinate [$\mu$m]', fontsize = 12)
ax3.set_ylabel('$\mu_e$ [cm$^2$ V$^{-1}$ s$^{-1}$]', fontsize = 12)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
#from matplotlib import ticker
#formatter = ticker.ScalarFormatter(useMathText=True)
#formatter.set_scientific(True)
#formatter.set_powerlimits((-1,1))
#axes.yaxis.set_major_formatter(formatter)
#ax3.set_xlim([0.01,3])
#ax3.set_ylim([5e-6, 3e-4])
ax3.grid('off')
#ax3.set_yticks(axes.get_yticks()[::1])
#ax3.set_xticks(axes.get_xticks()[::2])
#ax3.text(0.25, 7.5e-5, "V$_d$ = 3 V\nL$_c$ = 60 nm", fontsize = 14)
#ax3.set_yscale('log')

ax3.plot(x_moly_5_nm_gt_em, y_moly_5_nm_gt_em, color='red', linestyle='-', linewidth=3, label = 'L$_g$ = 5 nm')

#ax3.axvline(0.14, color = 'black')
#ax3.axvline(0.15, color = 'black')
ax3.legend(loc='lower right',ncol=4, fontsize = 14)

ax4 = fig.add_subplot(514)

ax4.set_xlabel('$x$ coordinate [$\mu$m]', fontsize = 12)
ax4.set_ylabel('$\phi$ [V]', fontsize = 12)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
#from matplotlib import ticker
#formatter = ticker.ScalarFormatter(useMathText=True)
#formatter.set_scientific(True)
#formatter.set_powerlimits((-1,1))
#axes.yaxis.set_major_formatter(formatter)
#ax4.set_xlim([0.01,3])
#ax4.set_ylim([5e-6, 3e-4])
ax4.grid('off')
#ax4.set_yticks(axes.get_yticks()[::1])
#ax4.set_xticks(axes.get_xticks()[::2])
#ax4.text(0.25, 7.5e-5, "V$_d$ = 3 V\nL$_c$ = 60 nm", fontsize = 14)
#ax4.set_yscale('log')

ax4.plot(x_moly_5_nm_gt_ep, y_moly_5_nm_gt_ep, color='midnightblue', linestyle='-', linewidth=3, label = 'L$_g$ = 5 nm')

#ax4.axvline(0.14, color = 'black')
#ax4.axvline(0.15, color = 'black')
ax4.legend(loc='lower right',ncol=4, fontsize = 14)

ax5 = fig.add_subplot(515)

ax5.set_xlabel('$x$ coordinate [$\mu$m]', fontsize = 12)
ax5.set_ylabel('Trap occupation [cm $^{-3}$ eV$^{-1}$]', fontsize = 12)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
#from matplotlib import ticker
#formatter = ticker.ScalarFormatter(useMathText=True)
#formatter.set_scientific(True)
#formatter.set_powerlimits((-1,1))
#axes.yaxis.set_major_formatter(formatter)
#ax5.set_xlim([0.01,3])
#ax5.set_ylim([5e-6, 3e-4])
ax5.grid('off')
#ax5.set_yticks(axes.get_yticks()[::1])
#ax5.set_xticks(axes.get_xticks()[::2])
#ax5.text(0.25, 7.5e-5, "V$_d$ = 3 V\nL$_c$ = 60 nm", fontsize = 14)
#ax5.set_yscale('log')

ax5.plot(x_moly_5_nm_gt_to, y_moly_5_nm_gt_to, color='purple', linestyle='-', linewidth=3, label = 'L$_g$ = 5 nm')

#ax5.axvline(0.14, color = 'black')
#ax5.axvline(0.15, color = 'black')
ax5.legend(loc='upper right',ncol=4, fontsize = 14)

plt.tight_layout()

plt.savefig("moly/moly_10_nm_gate_profiles.png",bbox_inches='tight', dpi = 300)
plt.show()

# %% [markdown]
# # Schottky_set
#
# ********

# %%
moly_2_nm_gt_Vd_0p1 = pd.read_csv("moly/Schottky_set/2_nm/moly_2_nm_gate_Vd_0p1.csv")
x_moly_2_nm_gt_Vd_0p1 = moly_2_nm_gt_Vd_0p1['x']
y_moly_2_nm_gt_Vd_0p1 = moly_2_nm_gt_Vd_0p1['y']

moly_2_nm_gt_Vd_0p3 = pd.read_csv("moly/Schottky_set/2_nm/moly_2_nm_gate_Vd_0p3.csv")
x_moly_2_nm_gt_Vd_0p3 = moly_2_nm_gt_Vd_0p3['x']
y_moly_2_nm_gt_Vd_0p3 = moly_2_nm_gt_Vd_0p3['y']

moly_2_nm_gt_Vd_0p4 = pd.read_csv("moly/Schottky_set/2_nm/moly_2_nm_gate_Vd_0p4.csv")
x_moly_2_nm_gt_Vd_0p4 = moly_2_nm_gt_Vd_0p4['x']
y_moly_2_nm_gt_Vd_0p4 = moly_2_nm_gt_Vd_0p4['y']

moly_2_nm_gt_Vd_1 = pd.read_csv("moly/Schottky_set/2_nm/moly_2_nm_gate_Vd_1.csv")
x_moly_2_nm_gt_Vd_1 = moly_2_nm_gt_Vd_1['x']
y_moly_2_nm_gt_Vd_1 = moly_2_nm_gt_Vd_1['y']

moly_3_nm_gt_Vd_0p1 = pd.read_csv("moly/Schottky_set/3_nm/moly_3_nm_gate_Vd_0p1.csv")
x_moly_3_nm_gt_Vd_0p1 = moly_3_nm_gt_Vd_0p1['x']
y_moly_3_nm_gt_Vd_0p1 = moly_3_nm_gt_Vd_0p1['y']

moly_3_nm_gt_Vd_0p3 = pd.read_csv("moly/Schottky_set/3_nm/moly_3_nm_gate_Vd_0p3.csv")
x_moly_3_nm_gt_Vd_0p3 = moly_3_nm_gt_Vd_0p3['x']
y_moly_3_nm_gt_Vd_0p3 = moly_3_nm_gt_Vd_0p3['y']

moly_3_nm_gt_Vd_0p4 = pd.read_csv("moly/Schottky_set/3_nm/moly_3_nm_gate_Vd_0p4.csv")
x_moly_3_nm_gt_Vd_0p4 = moly_3_nm_gt_Vd_0p4['x']
y_moly_3_nm_gt_Vd_0p4 = moly_3_nm_gt_Vd_0p4['y']

moly_3_nm_gt_Vd_1 = pd.read_csv("moly/Schottky_set/3_nm/moly_3_nm_gate_Vd_1.csv")
x_moly_3_nm_gt_Vd_1 = moly_3_nm_gt_Vd_1['x']
y_moly_3_nm_gt_Vd_1 = moly_3_nm_gt_Vd_1['y']

moly_3_nm_gt_Vd_3 = pd.read_csv("moly/Schottky_set/3_nm/moly_3_nm_gate_Vd_3.csv")
x_moly_3_nm_gt_Vd_3 = moly_3_nm_gt_Vd_3['x']
y_moly_3_nm_gt_Vd_3 = moly_3_nm_gt_Vd_3['y']

moly_4_nm_gt_Vd_0p1 = pd.read_csv("moly/Schottky_set/4_nm/moly_4_nm_gate_Vd_0p1.csv")
x_moly_4_nm_gt_Vd_0p1 = moly_4_nm_gt_Vd_0p1['x']
y_moly_4_nm_gt_Vd_0p1 = moly_4_nm_gt_Vd_0p1['y']

moly_4_nm_gt_Vd_0p3 = pd.read_csv("moly/Schottky_set/4_nm/moly_4_nm_gate_Vd_0p3.csv")
x_moly_4_nm_gt_Vd_0p3 = moly_4_nm_gt_Vd_0p3['x']
y_moly_4_nm_gt_Vd_0p3 = moly_4_nm_gt_Vd_0p3['y']

moly_4_nm_gt_Vd_0p4 = pd.read_csv("moly/Schottky_set/4_nm/moly_4_nm_gate_Vd_0p4.csv")
x_moly_4_nm_gt_Vd_0p4 = moly_4_nm_gt_Vd_0p4['x']
y_moly_4_nm_gt_Vd_0p4 = moly_4_nm_gt_Vd_0p4['y']

moly_4_nm_gt_Vd_1 = pd.read_csv("moly/Schottky_set/4_nm/moly_4_nm_gate_Vd_1.csv")
x_moly_4_nm_gt_Vd_1 = moly_4_nm_gt_Vd_1['x']
y_moly_4_nm_gt_Vd_1 = moly_4_nm_gt_Vd_1['y']

moly_4_nm_gt_Vd_3 = pd.read_csv("moly/Schottky_set/4_nm/moly_4_nm_gate_Vd_3.csv")
x_moly_4_nm_gt_Vd_3 = moly_4_nm_gt_Vd_3['x']
y_moly_4_nm_gt_Vd_3 = moly_4_nm_gt_Vd_3['y']

moly_5_nm_gt_Vd_0p1 = pd.read_csv("moly/Schottky_set/5_nm/moly_5_nm_gate_Vd_0p1.csv")
x_moly_5_nm_gt_Vd_0p1 = moly_5_nm_gt_Vd_0p1['x']
y_moly_5_nm_gt_Vd_0p1 = moly_5_nm_gt_Vd_0p1['y']

moly_5_nm_gt_Vd_0p3 = pd.read_csv("moly/Schottky_set/5_nm/moly_5_nm_gate_Vd_0p3.csv")
x_moly_5_nm_gt_Vd_0p3 = moly_5_nm_gt_Vd_0p3['x']
y_moly_5_nm_gt_Vd_0p3 = moly_5_nm_gt_Vd_0p3['y']

moly_5_nm_gt_Vd_0p4 = pd.read_csv("moly/Schottky_set/5_nm/moly_5_nm_gate_Vd_0p4.csv")
x_moly_5_nm_gt_Vd_0p4 = moly_5_nm_gt_Vd_0p4['x']
y_moly_5_nm_gt_Vd_0p4 = moly_5_nm_gt_Vd_0p4['y']

moly_5_nm_gt_Vd_1 = pd.read_csv("moly/Schottky_set/5_nm/moly_5_nm_gate_Vd_1.csv")
x_moly_5_nm_gt_Vd_1 = moly_5_nm_gt_Vd_1['x']
y_moly_5_nm_gt_Vd_1 = moly_5_nm_gt_Vd_1['y']

moly_5_nm_gt_Vd_3 = pd.read_csv("moly/Schottky_set/5_nm/moly_5_nm_gate_Vd_3.csv")
x_moly_5_nm_gt_Vd_3 = moly_5_nm_gt_Vd_3['x']
y_moly_5_nm_gt_Vd_3 = moly_5_nm_gt_Vd_3['y']

moly_10_nm_gt_Vd_0p1 = pd.read_csv("moly/Schottky_set/10_nm/moly_10_nm_gate_Vd_0p1.csv")
x_moly_10_nm_gt_Vd_0p1 = moly_10_nm_gt_Vd_0p1['x']
y_moly_10_nm_gt_Vd_0p1 = moly_10_nm_gt_Vd_0p1['y']

moly_10_nm_gt_Vd_0p3 = pd.read_csv("moly/Schottky_set/10_nm/moly_10_nm_gate_Vd_0p3.csv")
x_moly_10_nm_gt_Vd_0p3 = moly_10_nm_gt_Vd_0p3['x']
y_moly_10_nm_gt_Vd_0p3 = moly_10_nm_gt_Vd_0p3['y']

moly_10_nm_gt_Vd_0p4 = pd.read_csv("moly/Schottky_set/10_nm/moly_10_nm_gate_Vd_0p4.csv")
x_moly_10_nm_gt_Vd_0p4 = moly_10_nm_gt_Vd_0p4['x']
y_moly_10_nm_gt_Vd_0p4 = moly_10_nm_gt_Vd_0p4['y']

moly_10_nm_gt_Vd_1 = pd.read_csv("moly/Schottky_set/10_nm/moly_10_nm_gate_Vd_1.csv")
x_moly_10_nm_gt_Vd_1 = moly_10_nm_gt_Vd_1['x']
y_moly_10_nm_gt_Vd_1 = moly_10_nm_gt_Vd_1['y']

moly_10_nm_gt_Vd_3 = pd.read_csv("moly/Schottky_set/10_nm/moly_10_nm_gate_Vd_3.csv")
x_moly_10_nm_gt_Vd_3 = moly_10_nm_gt_Vd_3['x']
y_moly_10_nm_gt_Vd_3 = moly_10_nm_gt_Vd_3['y']

moly_100_nm_gt_Vd_0p1 = pd.read_csv("moly/Schottky_set/100_nm/moly_100_nm_gate_Vd_0p1.csv")
x_moly_100_nm_gt_Vd_0p1 = moly_100_nm_gt_Vd_0p1['x']
y_moly_100_nm_gt_Vd_0p1 = moly_100_nm_gt_Vd_0p1['y']

moly_100_nm_gt_Vd_0p3 = pd.read_csv("moly/Schottky_set/100_nm/moly_100_nm_gate_Vd_0p3.csv")
x_moly_100_nm_gt_Vd_0p3 = moly_100_nm_gt_Vd_0p3['x']
y_moly_100_nm_gt_Vd_0p3 = moly_100_nm_gt_Vd_0p3['y']

moly_100_nm_gt_Vd_0p4 = pd.read_csv("moly/Schottky_set/100_nm/moly_100_nm_gate_Vd_0p4.csv")
x_moly_100_nm_gt_Vd_0p4 = moly_100_nm_gt_Vd_0p4['x']
y_moly_100_nm_gt_Vd_0p4 = moly_100_nm_gt_Vd_0p4['y']

moly_100_nm_gt_Vd_1 = pd.read_csv("moly/Schottky_set/100_nm/moly_100_nm_gate_Vd_1.csv")
x_moly_100_nm_gt_Vd_1 = moly_100_nm_gt_Vd_1['x']
y_moly_100_nm_gt_Vd_1 = moly_100_nm_gt_Vd_1['y']

moly_100_nm_gt_Vd_3 = pd.read_csv("moly/Schottky_set/100_nm/moly_100_nm_gate_Vd_3.csv")
x_moly_100_nm_gt_Vd_3 = moly_100_nm_gt_Vd_3['x']
y_moly_100_nm_gt_Vd_3 = moly_100_nm_gt_Vd_3['y']

moly_200_nm_gt_Vd_1 = pd.read_csv("moly/Schottky_set/200_nm/moly_200_nm_gate_Vd_1.csv")
x_moly_200_nm_gt_Vd_1 = moly_200_nm_gt_Vd_1['x']
y_moly_200_nm_gt_Vd_1 = moly_200_nm_gt_Vd_1['y']

moly_200_nm_gt_Vd_3 = pd.read_csv("moly/Schottky_set/200_nm/moly_200_nm_gate_Vd_3.csv")
x_moly_200_nm_gt_Vd_3 = moly_200_nm_gt_Vd_3['x']
y_moly_200_nm_gt_Vd_3 = moly_200_nm_gt_Vd_3['y']

moly_2_nm_gt_Vd_0p3_ev = pd.read_csv("moly/Schottky_set/2_nm/moly_2_nm_gate_Vd_0p3_electron_velocity.csv")
x_moly_2_nm_gt_Vd_0p3_ev = moly_2_nm_gt_Vd_0p3_ev['eVelocity(C1(n66_des)) X']
y_moly_2_nm_gt_Vd_0p3_ev = moly_2_nm_gt_Vd_0p3_ev['eVelocity(C1(n66_des)) Y']

moly_2_nm_gt_Vd_0p3_em = pd.read_csv("moly/Schottky_set/2_nm/moly_2_nm_gate_Vd_0p3_electron_mobility.csv")
x_moly_2_nm_gt_Vd_0p3_em = moly_2_nm_gt_Vd_0p3_em['eMobility(C1(n66_des)) X']
y_moly_2_nm_gt_Vd_0p3_em = moly_2_nm_gt_Vd_0p3_em['eMobility(C1(n66_des)) Y']

moly_2_nm_gt_Vd_0p3_ep = pd.read_csv("moly/Schottky_set/2_nm/moly_2_nm_gate_Vd_0p3_electrostatic_potential.csv")
x_moly_2_nm_gt_Vd_0p3_ep = moly_2_nm_gt_Vd_0p3_ep['ElectrostaticPotential(C1(n66_des)) X']
y_moly_2_nm_gt_Vd_0p3_ep = moly_2_nm_gt_Vd_0p3_ep['ElectrostaticPotential(C1(n66_des)) Y']

moly_2_nm_gt_Vd_0p3_to = pd.read_csv("moly/Schottky_set/2_nm/moly_2_nm_gate_Vd_0p3_trap_occupation.csv")
x_moly_2_nm_gt_Vd_0p3_to = moly_2_nm_gt_Vd_0p3_to['Abs(TrapOccupation_0(eN:Ta)-V)(C1(n66_des)) X']
y_moly_2_nm_gt_Vd_0p3_to = moly_2_nm_gt_Vd_0p3_to['Abs(TrapOccupation_0(eN:Ta)-V)(C1(n66_des)) Y']

moly_2_nm_gt_Vd_0p3_ef = pd.read_csv("moly/Schottky_set/2_nm/moly_2_nm_gate_Vd_0p3_electric_field.csv")
x_moly_2_nm_gt_Vd_0p3_ef = moly_2_nm_gt_Vd_0p3_ef['Abs(ElectricField-V)(C1(n66_des)) X']
y_moly_2_nm_gt_Vd_0p3_ef = moly_2_nm_gt_Vd_0p3_ef['Abs(ElectricField-V)(C1(n66_des)) Y']

moly_2_nm_gt_Vd_0p3_bs = pd.read_csv("moly/Schottky_set/2_nm/moly_2_nm_gate_Vd_0p3_band_structure.csv")
Ec_x_moly_2_nm_gt_Vd_0p3_bs = moly_2_nm_gt_Vd_0p3_bs['Ec X']
Ec_y_moly_2_nm_gt_Vd_0p3_bs = moly_2_nm_gt_Vd_0p3_bs['Ec Y']
Ev_x_moly_2_nm_gt_Vd_0p3_bs = moly_2_nm_gt_Vd_0p3_bs['Ev X']
Ev_y_moly_2_nm_gt_Vd_0p3_bs = moly_2_nm_gt_Vd_0p3_bs['Ev Y']
Efn_x_moly_2_nm_gt_Vd_0p3_bs = moly_2_nm_gt_Vd_0p3_bs['Efn X']
Efn_y_moly_2_nm_gt_Vd_0p3_bs = moly_2_nm_gt_Vd_0p3_bs['Efn Y']
Efp_x_moly_2_nm_gt_Vd_0p3_bs = moly_2_nm_gt_Vd_0p3_bs['Efp X']
Efp_y_moly_2_nm_gt_Vd_0p3_bs = moly_2_nm_gt_Vd_0p3_bs['Efp Y']

# %%
fig = plt.figure(figsize=(10.5,5))

ax1 = fig.add_subplot(121)

ax1.set_xlabel('V$_g$ [V]', fontsize = 15)
ax1.set_ylabel('I$_d$ [A]', fontsize = 15)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
#from matplotlib import ticker
#formatter = ticker.ScalarFormatter(useMathText=True)
#formatter.set_scientific(True)
#formatter.set_powerlimits((-1,1))
#axes.yaxis.set_major_formatter(formatter)
ax1.set_xlim([0.01,3])
#ax1.set_ylim([1e-12, 1.4e-8])
#axes.grid('off')
#axes.set_yticks(axes.get_yticks()[::1])
#axes.set_xticks(axes.get_xticks()[::2])
ax1.text(1.25, 0.8e-8, "V$_d$ = 0.1 V\nL$_c$ = L$_g$ + 100 nm", fontsize = 14)
#ax1.set_yscale('log')
ax1.plot(x_moly_2_nm_gt_Vd_0p1, y_moly_2_nm_gt_Vd_0p1 , color='violet', linestyle='-', linewidth=3, label = 'L$_g$ = 2 nm')
ax1.plot(x_moly_3_nm_gt_Vd_0p1, y_moly_3_nm_gt_Vd_0p1 , color='dodgerblue', linestyle='-', linewidth=3, label = 'L$_g$ = 3 nm')
ax1.plot(x_moly_4_nm_gt_Vd_0p1, y_moly_4_nm_gt_Vd_0p1 , color='grey', linestyle='-', linewidth=3, label = 'L$_g$ = 4 nm')
ax1.plot(x_moly_5_nm_gt_Vd_0p1, y_moly_5_nm_gt_Vd_0p1 , color='midnightblue', linestyle='-', linewidth=3, label = 'L$_g$ = 5 nm')
ax1.plot(x_moly_10_nm_gt_Vd_0p1, y_moly_10_nm_gt_Vd_0p1 , color='forestgreen', linestyle='-', linewidth=3, label = 'L$_g$ = 10 nm')
ax1.plot(x_moly_100_nm_gt_Vd_0p1, y_moly_100_nm_gt_Vd_0p1 , color='red', linestyle='-', linewidth=3, label = 'L$_g$ = 100 nm')
#ax1.plot(x_moly_200_nm_gt_Vd_0p1, y_moly_200_nm_gt_Vd_0p1 , color='black', linestyle='-', linewidth=3, label = 'L$_g$ = 200 nm')

ax1.legend(loc='lower right',ncol=1, fontsize = 14)

ax2 = fig.add_subplot(122)

ax2.set_xlabel('V$_g$ [V]', fontsize = 15)
ax2.set_ylabel('I$_d$ [A]', fontsize = 15)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
#from matplotlib import ticker
#formatter = ticker.ScalarFormatter(useMathText=True)
#formatter.set_scientific(True)
#formatter.set_powerlimits((-1,1))
#axes.yaxis.set_major_formatter(formatter)
ax2.set_xlim([0.01,0.5])
ax2.set_ylim([5e-9, 1.23e-8])
#axes.grid('off')
#axes.set_yticks(axes.get_yticks()[::1])
#axes.set_xticks(axes.get_xticks()[::2])
#ax2.text(0.5, 3e-8, "V$_d$ = 0.1 V\nL$_c$ = L$_g$ + 100 nm", fontsize = 14)
#ax2.set_yscale('log')
ax2.plot(x_moly_2_nm_gt_Vd_0p1, y_moly_2_nm_gt_Vd_0p1 , color='violet', linestyle='-', linewidth=3, label = 'L$_g$ = 2 nm')
ax2.plot(x_moly_3_nm_gt_Vd_0p1, y_moly_3_nm_gt_Vd_0p1 , color='dodgerblue', linestyle='-', linewidth=3, label = 'L$_g$ = 3 nm')
ax2.plot(x_moly_4_nm_gt_Vd_0p1, y_moly_4_nm_gt_Vd_0p1 , color='grey', linestyle='-', linewidth=3, label = 'L$_g$ = 4 nm')
ax2.plot(x_moly_5_nm_gt_Vd_0p1, y_moly_5_nm_gt_Vd_0p1 , color='midnightblue', linestyle='-', linewidth=3, label = 'L$_g$ = 5 nm')
ax2.plot(x_moly_10_nm_gt_Vd_0p1, y_moly_10_nm_gt_Vd_0p1 , color='forestgreen', linestyle='-', linewidth=3, label = 'L$_g$ = 10 nm')
ax2.plot(x_moly_100_nm_gt_Vd_0p1, y_moly_100_nm_gt_Vd_0p1 , color='red', linestyle='-', linewidth=3, label = 'L$_g$ = 100 nm')
#ax2.plot(x_moly_200_nm_gt_Vd_0p1, y_moly_200_nm_gt_Vd_0p1 , color='black', linestyle='-', linewidth=3, label = 'L$_g$ = 200 nm')


ax2.legend(loc='lower right',ncol=1, fontsize = 14)

plt.tight_layout()

plt.savefig("moly/Schottky_set/moly_different_gates_Vd_0p1.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(10.5,5))

ax1 = fig.add_subplot(121)

ax1.set_xlabel('V$_g$ [V]', fontsize = 15)
ax1.set_ylabel('I$_d$ [A]', fontsize = 15)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
#from matplotlib import ticker
#formatter = ticker.ScalarFormatter(useMathText=True)
#formatter.set_scientific(True)
#formatter.set_powerlimits((-1,1))
#axes.yaxis.set_major_formatter(formatter)
ax1.set_xlim([0.01,3])
#ax1.set_ylim([1e-12, 1.4e-8])
#axes.grid('off')
#axes.set_yticks(axes.get_yticks()[::1])
#axes.set_xticks(axes.get_xticks()[::2])
ax1.text(0.65, 1e-6, "SS = 60 mV/dec", fontsize = 14)
#ax1.set_yscale('log')
ax1.plot(x_moly_2_nm_gt_Vd_0p3, y_moly_2_nm_gt_Vd_0p3 , color='violet', linestyle='-', linewidth=3, label = 'L$_g$ = 2 nm')
ax1.plot(x_moly_3_nm_gt_Vd_0p3, y_moly_3_nm_gt_Vd_0p3 , color='dodgerblue', linestyle='-', linewidth=3, label = 'L$_g$ = 3 nm')
ax1.plot(x_moly_4_nm_gt_Vd_0p3, y_moly_4_nm_gt_Vd_0p3 , color='grey', linestyle='-', linewidth=3, label = 'L$_g$ = 4 nm')
ax1.plot(x_moly_5_nm_gt_Vd_0p3, abs(y_moly_5_nm_gt_Vd_0p3) , color='midnightblue', linestyle='-', linewidth=3, label = 'L$_g$ = 5 nm')
ax1.plot(x_moly_10_nm_gt_Vd_0p3, abs(y_moly_10_nm_gt_Vd_0p3) , color='forestgreen', linestyle='-', linewidth=3, label = 'L$_g$ = 10 nm')
ax1.plot(x_moly_100_nm_gt_Vd_0p3, abs(y_moly_100_nm_gt_Vd_0p3) , color='red', linestyle='-', linewidth=3, label = 'L$_g$ = 100 nm')
#ax1.plot(x_moly_200_nm_gt_Vd_0p3, y_moly_200_nm_gt_Vd_0p3 , color='black', linestyle='-', linewidth=3, label = 'L$_g$ = 200 nm')
ax1.plot(x,y, '--', lw = 2, color = 'midnightblue')
#ax1.legend(loc='best',ncol=2, fontsize = 11)

ax2 = fig.add_subplot(122)

ax2.set_xlabel('V$_g$ [V]', fontsize = 15)
ax2.set_ylabel('I$_d$ [A]', fontsize = 15)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
#from matplotlib import ticker
#formatter = ticker.ScalarFormatter(useMathText=True)
#formatter.set_scientific(True)
#formatter.set_powerlimits((-1,1))
#axes.yaxis.set_major_formatter(formatter)
ax2.set_xlim([0.01,0.5])
#ax2.set_ylim([5e-9, 1.23e-5])
#axes.grid('off')
#axes.set_yticks(axes.get_yticks()[::1])
#axes.set_xticks(axes.get_xticks()[::2])
ax2.text(0.05, 3e-18, "V$_d$ = 0.3 V\nL$_c$ = L$_g$ + 100 nm", fontsize = 14)
ax2.set_yscale('log')
ax2.plot(x_moly_2_nm_gt_Vd_0p3, y_moly_2_nm_gt_Vd_0p3 , color='violet', linestyle='-', linewidth=3, label = 'L$_g$ = 2 nm')
ax2.plot(x_moly_3_nm_gt_Vd_0p3, y_moly_3_nm_gt_Vd_0p3 , color='dodgerblue', linestyle='-', linewidth=3, label = 'L$_g$ = 3 nm')
ax2.plot(x_moly_4_nm_gt_Vd_0p3, y_moly_4_nm_gt_Vd_0p3 , color='grey', linestyle='-', linewidth=3, label = 'L$_g$ = 4 nm')
ax2.plot(x_moly_5_nm_gt_Vd_0p3, y_moly_5_nm_gt_Vd_0p3 , color='midnightblue', linestyle='-', linewidth=3, label = 'L$_g$ = 5 nm')
ax2.plot(x_moly_10_nm_gt_Vd_0p3, y_moly_10_nm_gt_Vd_0p3 , color='forestgreen', linestyle='-', linewidth=3, label = 'L$_g$ = 10 nm')
ax2.plot(x_moly_100_nm_gt_Vd_0p3, y_moly_100_nm_gt_Vd_0p3 , color='red', linestyle='-', linewidth=3, label = 'L$_g$ = 100 nm')
#ax2.plot(x_moly_200_nm_gt_Vd_0p3, y_moly_200_nm_gt_Vd_0p3 , color='black', linestyle='-', linewidth=3, label = 'L$_g$ = 200 nm')


ax2.legend(loc='lower right',ncol=2, fontsize = 11)

plt.tight_layout()

plt.savefig("moly/Schottky_set/moly_different_gates_Vd_0p3.png", bbox_inches = 'tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(10.5,5))

ax1 = fig.add_subplot(121)

ax1.set_xlabel('V$_g$ [V]', fontsize = 15)
ax1.set_ylabel('I$_d$ [A]', fontsize = 15)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
#from matplotlib import ticker
#formatter = ticker.ScalarFormatter(useMathText=True)
#formatter.set_scientific(True)
#formatter.set_powerlimits((-1,1))
#axes.yaxis.set_major_formatter(formatter)
ax1.set_xlim([0.01,3])
#ax1.set_ylim([1e-12, 1.4e-8])
#axes.grid('off')
#axes.set_yticks(axes.get_yticks()[::1])
#axes.set_xticks(axes.get_xticks()[::2])
#ax1.text(1.25, 0.8e-8, "V$_d$ = 0.3 V\nL$_c$ = L$_g$ + 100 nm", fontsize = 14)
#ax1.set_yscale('log')
ax1.plot(x_moly_2_nm_gt_Vd_0p4, y_moly_2_nm_gt_Vd_0p4 , color='violet', linestyle='-', linewidth=3, label = 'L$_g$ = 2 nm')
ax1.plot(x_moly_3_nm_gt_Vd_0p4, y_moly_3_nm_gt_Vd_0p4 , color='dodgerblue', linestyle='-', linewidth=3, label = 'L$_g$ = 3 nm')
ax1.plot(x_moly_4_nm_gt_Vd_0p4, y_moly_4_nm_gt_Vd_0p4 , color='grey', linestyle='-', linewidth=3, label = 'L$_g$ = 4 nm')
ax1.plot(x_moly_5_nm_gt_Vd_0p4, y_moly_5_nm_gt_Vd_0p4 , color='midnightblue', linestyle='-', linewidth=3, label = 'L$_g$ = 5 nm')
ax1.plot(x_moly_10_nm_gt_Vd_0p4, y_moly_10_nm_gt_Vd_0p4 , color='forestgreen', linestyle='-', linewidth=3, label = 'L$_g$ = 10 nm')
ax1.plot(x_moly_100_nm_gt_Vd_0p4, y_moly_100_nm_gt_Vd_0p4 , color='red', linestyle='-', linewidth=3, label = 'L$_g$ = 100 nm')
#ax1.plot(x_moly_200_nm_gt_Vd_0p4, y_moly_200_nm_gt_Vd_0p4 , color='black', linestyle='-', linewidth=3, label = 'L$_g$ = 200 nm')

ax1.legend(loc='best',ncol=1, fontsize = 14)

ax2 = fig.add_subplot(122)

ax2.set_xlabel('V$_g$ [V]', fontsize = 15)
ax2.set_ylabel('I$_d$ [A]', fontsize = 15)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
#from matplotlib import ticker
#formatter = ticker.ScalarFormatter(useMathText=True)
#formatter.set_scientific(True)
#formatter.set_powerlimits((-1,1))
#axes.yaxis.set_major_formatter(formatter)
ax2.set_xlim([0.01,0.5])
#ax2.set_ylim([5e-9, 1.23e-5])
#axes.grid('off')
#axes.set_yticks(axes.get_yticks()[::1])
#axes.set_xticks(axes.get_xticks()[::2])
ax2.text(0.05, 3e-17, "V$_d$ = 0.4 V\nL$_c$ = L$_g$ + 100 nm", fontsize = 14)
ax2.set_yscale('log')
ax2.plot(x_moly_2_nm_gt_Vd_0p4, y_moly_2_nm_gt_Vd_0p4 , color='violet', linestyle='-', linewidth=3, label = 'L$_g$ = 2 nm')
ax2.plot(x_moly_3_nm_gt_Vd_0p4, y_moly_3_nm_gt_Vd_0p4 , color='dodgerblue', linestyle='-', linewidth=3, label = 'L$_g$ = 3 nm')
ax2.plot(x_moly_4_nm_gt_Vd_0p4, y_moly_4_nm_gt_Vd_0p4 , color='grey', linestyle='-', linewidth=3, label = 'L$_g$ = 4 nm')
ax2.plot(x_moly_5_nm_gt_Vd_0p4, y_moly_5_nm_gt_Vd_0p4 , color='midnightblue', linestyle='-', linewidth=3, label = 'L$_g$ = 5 nm')
ax2.plot(x_moly_10_nm_gt_Vd_0p4, y_moly_10_nm_gt_Vd_0p4 , color='forestgreen', linestyle='-', linewidth=3, label = 'L$_g$ = 10 nm')
ax2.plot(x_moly_100_nm_gt_Vd_0p4, y_moly_100_nm_gt_Vd_0p4 , color='red', linestyle='-', linewidth=3, label = 'L$_g$ = 100 nm')
#ax2.plot(x_moly_200_nm_gt_Vd_0p4, y_moly_200_nm_gt_Vd_0p4 , color='black', linestyle='-', linewidth=3, label = 'L$_g$ = 200 nm')


ax2.legend(loc='lower right',ncol=2, fontsize = 11.4)

plt.tight_layout()

plt.savefig("moly/Schottky_set/moly_different_gates_Vd_0p4.png", bbox_inches = 'tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(10.5,5))

ax1 = fig.add_subplot(121)

ax1.set_xlabel('V$_g$ [V]', fontsize = 15)
ax1.set_ylabel('I$_d$ [A]', fontsize = 15)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
#from matplotlib import ticker
#formatter = ticker.ScalarFormatter(useMathText=True)
#formatter.set_scientific(True)
#formatter.set_powerlimits((-1,1))
#axes.yaxis.set_major_formatter(formatter)
ax1.set_xlim([0.01,3])
#ax1.set_ylim([1e-12, 1.4e-8])
#axes.grid('off')
#axes.set_yticks(axes.get_yticks()[::1])
#axes.set_xticks(axes.get_xticks()[::2])
#ax1.text(1.25, 0.8e-8, "V$_d$ = 0.3 V\nL$_c$ = L$_g$ + 100 nm", fontsize = 14)
#ax1.set_yscale('log')
ax1.plot(x_moly_2_nm_gt_Vd_1, y_moly_2_nm_gt_Vd_1 , color='violet', linestyle='-', linewidth=3, label = 'L$_g$ = 2 nm')
ax1.plot(x_moly_3_nm_gt_Vd_1, y_moly_3_nm_gt_Vd_1 , color='dodgerblue', linestyle='-', linewidth=3, label = 'L$_g$ = 3 nm')
ax1.plot(x_moly_4_nm_gt_Vd_1, y_moly_4_nm_gt_Vd_1 , color='grey', linestyle='-', linewidth=3, label = 'L$_g$ = 4 nm')
ax1.plot(x_moly_5_nm_gt_Vd_1, y_moly_5_nm_gt_Vd_1 , color='midnightblue', linestyle='-', linewidth=3, label = 'L$_g$ = 5 nm')
ax1.plot(x_moly_10_nm_gt_Vd_1, y_moly_10_nm_gt_Vd_1 , color='forestgreen', linestyle='-', linewidth=3, label = 'L$_g$ = 10 nm')
ax1.plot(x_moly_100_nm_gt_Vd_1, y_moly_100_nm_gt_Vd_1 , color='red', linestyle='-', linewidth=3, label = 'L$_g$ = 100 nm')
ax1.plot(x_moly_200_nm_gt_Vd_1, y_moly_200_nm_gt_Vd_1 , color='black', linestyle='-', linewidth=3, label = 'L$_g$ = 200 nm')

#ax1.legend(loc='best',ncol=1, fontsize = 14)

ax2 = fig.add_subplot(122)

ax2.set_xlabel('V$_g$ [V]', fontsize = 15)
ax2.set_ylabel('I$_d$ [A]', fontsize = 15)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
#from matplotlib import ticker
#formatter = ticker.ScalarFormatter(useMathText=True)
#formatter.set_scientific(True)
#formatter.set_powerlimits((-1,1))
#axes.yaxis.set_major_formatter(formatter)
ax2.set_xlim([0.01,0.5])
#ax2.set_ylim([5e-9, 1.23e-5])
#axes.grid('off')
#axes.set_yticks(axes.get_yticks()[::1])
#axes.set_xticks(axes.get_xticks()[::2])
ax2.text(0.05, 3e-17, "V$_d$ = 1 V\nL$_c$ = L$_g$ + 100 nm", fontsize = 14)
ax2.set_yscale('log')
ax2.plot(x_moly_2_nm_gt_Vd_1, y_moly_2_nm_gt_Vd_1 , color='violet', linestyle='-', linewidth=3, label = 'L$_g$ = 2 nm')
ax2.plot(x_moly_3_nm_gt_Vd_1, y_moly_3_nm_gt_Vd_1 , color='dodgerblue', linestyle='-', linewidth=3, label = 'L$_g$ = 3 nm')
ax2.plot(x_moly_4_nm_gt_Vd_1, y_moly_4_nm_gt_Vd_1 , color='grey', linestyle='-', linewidth=3, label = 'L$_g$ = 4 nm')
ax2.plot(x_moly_5_nm_gt_Vd_1, y_moly_5_nm_gt_Vd_1 , color='midnightblue', linestyle='-', linewidth=3, label = 'L$_g$ = 5 nm')
ax2.plot(x_moly_10_nm_gt_Vd_1, y_moly_10_nm_gt_Vd_1 , color='forestgreen', linestyle='-', linewidth=3, label = 'L$_g$ = 10 nm')
ax2.plot(x_moly_100_nm_gt_Vd_1, y_moly_100_nm_gt_Vd_1 , color='red', linestyle='-', linewidth=3, label = 'L$_g$ = 100 nm')
ax2.plot(x_moly_200_nm_gt_Vd_1, y_moly_200_nm_gt_Vd_1 , color='black', linestyle='-', linewidth=3, label = 'L$_g$ = 200 nm')


ax2.legend(loc='lower right',ncol=2, fontsize = 11.4)

plt.tight_layout()

plt.savefig("moly/Schottky_set/moly_different_gates_Vd_1.png", bbox_inches = 'tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(10.5,5))

ax1 = fig.add_subplot(121)

ax1.set_xlabel('V$_g$ [V]', fontsize = 15)
ax1.set_ylabel('I$_d$ [A]', fontsize = 15)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
#from matplotlib import ticker
#formatter = ticker.ScalarFormatter(useMathText=True)
#formatter.set_scientific(True)
#formatter.set_powerlimits((-1,1))
#axes.yaxis.set_major_formatter(formatter)
ax1.set_xlim([0.01,3])
#ax1.set_ylim([1e-12, 1.4e-8])
#axes.grid('off')
#axes.set_yticks(axes.get_yticks()[::1])
#axes.set_xticks(axes.get_xticks()[::2])
ax1.text(0.5, 6e-6, "V$_d$ = 3 V\nL$_c$ = L$_g$ + 100 nm", fontsize = 14)
#ax1.set_yscale('log')
ax1.plot(x_moly_2_nm_gt_Vd_3, y_moly_2_nm_gt_Vd_3 , color='violet', linestyle='-', linewidth=3, label = 'L$_g$ = 2 nm')
ax1.plot(x_moly_3_nm_gt_Vd_3, y_moly_3_nm_gt_Vd_3 , color='dodgerblue', linestyle='-', linewidth=3, label = 'L$_g$ = 3 nm')
ax1.plot(x_moly_4_nm_gt_Vd_3, y_moly_4_nm_gt_Vd_3 , color='grey', linestyle='-', linewidth=3, label = 'L$_g$ = 4 nm')
ax1.plot(x_moly_5_nm_gt_Vd_3, y_moly_5_nm_gt_Vd_3 , color='midnightblue', linestyle='-', linewidth=3, label = 'L$_g$ = 5 nm')
ax1.plot(x_moly_10_nm_gt_Vd_3, y_moly_10_nm_gt_Vd_3 , color='forestgreen', linestyle='-', linewidth=3, label = 'L$_g$ = 10 nm')
ax1.plot(x_moly_100_nm_gt_Vd_3, y_moly_100_nm_gt_Vd_3 , color='red', linestyle='-', linewidth=3, label = 'L$_g$ = 100 nm')
ax1.plot(x_moly_200_nm_gt_Vd_3, y_moly_200_nm_gt_Vd_3 , color='black', linestyle='-', linewidth=3, label = 'L$_g$ = 200 nm')

#ax1.legend(loc='best',ncol=1, fontsize = 14)

ax2 = fig.add_subplot(122)

ax2.set_xlabel('V$_g$ [V]', fontsize = 15)
ax2.set_ylabel('I$_d$ [A]', fontsize = 15)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
#from matplotlib import ticker
#formatter = ticker.ScalarFormatter(useMathText=True)
#formatter.set_scientific(True)
#formatter.set_powerlimits((-1,1))
#axes.yaxis.set_major_formatter(formatter)
ax2.set_xlim([0.01,0.5])
#ax2.set_ylim([5e-9, 1.23e-5])
#axes.grid('off')
#axes.set_yticks(axes.get_yticks()[::1])
#axes.set_xticks(axes.get_xticks()[::2])
#ax2.text(0.5, 3e-8, "V$_d$ = 0.1 V\nL$_c$ = L$_g$ + 100 nm", fontsize = 14)
ax2.set_yscale('log')
ax2.plot(x_moly_2_nm_gt_Vd_3, y_moly_2_nm_gt_Vd_3 , color='violet', linestyle='-', linewidth=3, label = 'L$_g$ = 2 nm')
ax2.plot(x_moly_3_nm_gt_Vd_3, y_moly_3_nm_gt_Vd_3 , color='dodgerblue', linestyle='-', linewidth=3, label = 'L$_g$ = 3 nm')
ax2.plot(x_moly_4_nm_gt_Vd_3, y_moly_4_nm_gt_Vd_3 , color='grey', linestyle='-', linewidth=3, label = 'L$_g$ = 4 nm')
ax2.plot(x_moly_5_nm_gt_Vd_3, y_moly_5_nm_gt_Vd_3 , color='midnightblue', linestyle='-', linewidth=3, label = 'L$_g$ = 5 nm')
ax2.plot(x_moly_10_nm_gt_Vd_3, y_moly_10_nm_gt_Vd_3 , color='forestgreen', linestyle='-', linewidth=3, label = 'L$_g$ = 10 nm')
ax2.plot(x_moly_100_nm_gt_Vd_3, y_moly_100_nm_gt_Vd_3 , color='red', linestyle='-', linewidth=3, label = 'L$_g$ = 100 nm')
ax2.plot(x_moly_200_nm_gt_Vd_3, y_moly_200_nm_gt_Vd_3 , color='black', linestyle='-', linewidth=3, label = 'L$_g$ = 200 nm')


ax2.legend(loc='lower right',ncol=1, fontsize = 14)

plt.tight_layout()

plt.savefig("moly/Schottky_set/moly_different_gates_Vd_3.png", bbox_inches = 'tight', dpi = 300)
plt.show()

# %%
y_moly_2_nm_gt_Vd_0p3[80]
# Out:
# 4.82923e-07

# %%
fig = plt.figure(figsize=(10.5,5))

ax1 = fig.add_subplot(121)

ax1.set_xlabel('V$_g$ [V]', fontsize = 15)
ax1.set_ylabel('I$_d$ [A]', fontsize = 15)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
#from matplotlib import ticker
#formatter = ticker.ScalarFormatter(useMathText=True)
#formatter.set_scientific(True)
#formatter.set_powerlimits((-1,1))
#axes.yaxis.set_major_formatter(formatter)
ax1.set_xlim([0.01,3])
#ax1.set_ylim([1e-12, 1.4e-8])
#axes.grid('off')
#axes.set_yticks(axes.get_yticks()[::1])
#axes.set_xticks(axes.get_xticks()[::2])
ax1.text(1, 4e-6, "L$_g$ = 2 nm\nL$_c$ = L$_g$ + 100 nm", fontsize = 14)
#ax1.set_yscale('log')
ax1.plot(x_moly_2_nm_gt_Vd_0p1, y_moly_2_nm_gt_Vd_0p1 , color='violet', linestyle='-', linewidth=3, label = 'V$_D$ = 0.1 V')
ax1.plot(x_moly_2_nm_gt_Vd_0p3, y_moly_2_nm_gt_Vd_0p3 , color='dodgerblue', linestyle='-', linewidth=3, label = 'V$_D$ = 0.3 V')
ax1.plot(x_moly_2_nm_gt_Vd_0p4, y_moly_2_nm_gt_Vd_0p4 , color='grey', linestyle='-', linewidth=3, label = 'V$_D$ = 0.4 V')
ax1.plot(x_moly_2_nm_gt_Vd_1, y_moly_2_nm_gt_Vd_1 , color='midnightblue', linestyle='-', linewidth=3, label = 'V$_D$ = 1 V')
ax1.plot(x_moly_2_nm_gt_Vd_3, y_moly_2_nm_gt_Vd_3 , color='forestgreen', linestyle='-', linewidth=3, label = 'V$_D$ = 3 V')
#ax1.legend(loc='best',ncol=1, fontsize = 14)

ax2 = fig.add_subplot(122)

ax2.set_xlabel('V$_g$ [V]', fontsize = 15)
ax2.set_ylabel('I$_d$ [A]', fontsize = 15)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
#from matplotlib import ticker
#formatter = ticker.ScalarFormatter(useMathText=True)
#formatter.set_scientific(True)
#formatter.set_powerlimits((-1,1))
#axes.yaxis.set_major_formatter(formatter)
ax2.set_xlim([0.01,0.5])
ax2.set_ylim([5e-9, 1.23e-5])
#axes.grid('off')
#axes.set_yticks(axes.get_yticks()[::1])
#axes.set_xticks(axes.get_xticks()[::2])
#ax2.text(0.5, 3e-8, "V$_d$ = 0.1 V\nL$_c$ = L$_g$ + 100 nm", fontsize = 14)
ax2.set_yscale('log')
ax2.plot(x_moly_2_nm_gt_Vd_0p1, y_moly_2_nm_gt_Vd_0p1 , color='violet', linestyle='-', linewidth=3, label = 'V$_D$ = 0.1 V')
ax2.plot(x_moly_2_nm_gt_Vd_0p3, y_moly_2_nm_gt_Vd_0p3 , color='dodgerblue', linestyle='-', linewidth=3, label = 'V$_D$ = 0.3 V')
ax2.plot(x_moly_2_nm_gt_Vd_0p4, y_moly_2_nm_gt_Vd_0p4 , color='grey', linestyle='-', linewidth=3, label = 'V$_D$ = 0.4 V')
ax2.plot(x_moly_2_nm_gt_Vd_1, y_moly_2_nm_gt_Vd_1 , color='midnightblue', linestyle='-', linewidth=3, label = 'V$_D$ = 1 V')
ax2.plot(x_moly_2_nm_gt_Vd_3, y_moly_2_nm_gt_Vd_3 , color='forestgreen', linestyle='-', linewidth=3, label = 'V$_D$ = 3 V')



ax2.legend(loc='best',ncol=2, fontsize = 12)

plt.tight_layout()

plt.savefig("moly/Schottky_set/moly_2_nm_gate_different_Vd.png", bbox_inches = 'tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(10.5,5))

ax1 = fig.add_subplot(121)

ax1.set_xlabel('V$_g$ [V]', fontsize = 15)
ax1.set_ylabel('I$_d$ [A]', fontsize = 15)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
#from matplotlib import ticker
#formatter = ticker.ScalarFormatter(useMathText=True)
#formatter.set_scientific(True)
#formatter.set_powerlimits((-1,1))
#axes.yaxis.set_major_formatter(formatter)
ax1.set_xlim([0.01,3])
#ax1.set_ylim([1e-12, 1.4e-8])
#axes.grid('off')
#axes.set_yticks(axes.get_yticks()[::1])
#axes.set_xticks(axes.get_xticks()[::2])
ax1.text(1, 1e-6, "L$_g$ = 3 nm\nL$_c$ = L$_g$ + 100 nm", fontsize = 14)
#ax1.set_yscale('log')
ax1.plot(x_moly_3_nm_gt_Vd_0p1, y_moly_3_nm_gt_Vd_0p1 , color='violet', linestyle='-', linewidth=3, label = 'V$_D$ = 0.1 V')
ax1.plot(x_moly_3_nm_gt_Vd_0p3, y_moly_3_nm_gt_Vd_0p3 , color='dodgerblue', linestyle='-', linewidth=3, label = 'V$_D$ = 0.3 V')
ax1.plot(x_moly_3_nm_gt_Vd_0p4, y_moly_3_nm_gt_Vd_0p4 , color='grey', linestyle='-', linewidth=3, label = 'V$_D$ = 0.4 V')
ax1.plot(x_moly_3_nm_gt_Vd_1, y_moly_3_nm_gt_Vd_1 , color='midnightblue', linestyle='-', linewidth=3, label = 'V$_D$ = 1 V')
ax1.plot(x_moly_3_nm_gt_Vd_3, y_moly_3_nm_gt_Vd_3 , color='forestgreen', linestyle='-', linewidth=3, label = 'V$_D$ = 3 V')
#ax1.legend(loc='best',ncol=1, fontsize = 14)

ax2 = fig.add_subplot(122)

ax2.set_xlabel('V$_g$ [V]', fontsize = 15)
ax2.set_ylabel('I$_d$ [A]', fontsize = 15)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
#from matplotlib import ticker
#formatter = ticker.ScalarFormatter(useMathText=True)
#formatter.set_scientific(True)
#formatter.set_powerlimits((-1,1))
#axes.yaxis.set_major_formatter(formatter)
ax2.set_xlim([0.01,0.5])
#ax2.set_ylim([5e-9, 1.23e-5])
#axes.grid('off')
#axes.set_yticks(axes.get_yticks()[::1])
#axes.set_xticks(axes.get_xticks()[::2])
#ax2.text(0.5, 3e-8, "V$_d$ = 0.1 V\nL$_c$ = L$_g$ + 100 nm", fontsize = 14)
ax2.set_yscale('log')
ax2.plot(x_moly_3_nm_gt_Vd_0p1, y_moly_3_nm_gt_Vd_0p1 , color='violet', linestyle='-', linewidth=3, label = 'V$_D$ = 0.1 V')
ax2.plot(x_moly_3_nm_gt_Vd_0p3, y_moly_3_nm_gt_Vd_0p3 , color='dodgerblue', linestyle='-', linewidth=3, label = 'V$_D$ = 0.3 V')
ax2.plot(x_moly_3_nm_gt_Vd_0p4, y_moly_3_nm_gt_Vd_0p4 , color='grey', linestyle='-', linewidth=3, label = 'V$_D$ = 0.4 V')
ax2.plot(x_moly_3_nm_gt_Vd_1, y_moly_3_nm_gt_Vd_1 , color='midnightblue', linestyle='-', linewidth=3, label = 'V$_D$ = 1 V')
ax2.plot(x_moly_3_nm_gt_Vd_3, y_moly_3_nm_gt_Vd_3 , color='forestgreen', linestyle='-', linewidth=3, label = 'V$_D$ = 3 V')



ax2.legend(loc='best',ncol=2, fontsize = 12)

plt.tight_layout()

plt.savefig("moly/Schottky_set/moly_3_nm_gate_different_Vd.png", bbox_inches = 'tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(10.5,5))

ax1 = fig.add_subplot(121)

ax1.set_xlabel('V$_g$ [V]', fontsize = 15)
ax1.set_ylabel('I$_d$ [A]', fontsize = 15)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
#from matplotlib import ticker
#formatter = ticker.ScalarFormatter(useMathText=True)
#formatter.set_scientific(True)
#formatter.set_powerlimits((-1,1))
#axes.yaxis.set_major_formatter(formatter)
ax1.set_xlim([0.01,3])
#ax1.set_ylim([1e-12, 1.4e-8])
#axes.grid('off')
#axes.set_yticks(axes.get_yticks()[::1])
#axes.set_xticks(axes.get_xticks()[::2])
ax1.text(1, 2e-6, "L$_g$ = 4 nm\nL$_c$ = L$_g$ + 100 nm", fontsize = 14)
#ax1.set_yscale('log')
ax1.plot(x_moly_4_nm_gt_Vd_0p1, y_moly_4_nm_gt_Vd_0p1 , color='violet', linestyle='-', linewidth=3, label = 'V$_D$ = 0.1 V')
ax1.plot(x_moly_4_nm_gt_Vd_0p3, y_moly_4_nm_gt_Vd_0p3 , color='dodgerblue', linestyle='-', linewidth=3, label = 'V$_D$ = 0.3 V')
ax1.plot(x_moly_4_nm_gt_Vd_0p4, y_moly_4_nm_gt_Vd_0p4 , color='grey', linestyle='-', linewidth=3, label = 'V$_D$ = 0.4 V')
ax1.plot(x_moly_4_nm_gt_Vd_1, y_moly_4_nm_gt_Vd_1 , color='midnightblue', linestyle='-', linewidth=3, label = 'V$_D$ = 1 V')
ax1.plot(x_moly_4_nm_gt_Vd_3, y_moly_4_nm_gt_Vd_3 , color='forestgreen', linestyle='-', linewidth=3, label = 'V$_D$ = 3 V')
#ax1.legend(loc='best',ncol=1, fontsize = 14)

ax2 = fig.add_subplot(122)

ax2.set_xlabel('V$_g$ [V]', fontsize = 15)
ax2.set_ylabel('I$_d$ [A]', fontsize = 15)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
#from matplotlib import ticker
#formatter = ticker.ScalarFormatter(useMathText=True)
#formatter.set_scientific(True)
#formatter.set_powerlimits((-1,1))
#axes.yaxis.set_major_formatter(formatter)
ax2.set_xlim([0.01,0.5])
#ax2.set_ylim([5e-9, 1.23e-5])
#axes.grid('off')
#axes.set_yticks(axes.get_yticks()[::1])
#axes.set_xticks(axes.get_xticks()[::2])
#ax2.text(0.5, 3e-8, "V$_d$ = 0.1 V\nL$_c$ = L$_g$ + 100 nm", fontsize = 14)
ax2.set_yscale('log')
ax2.plot(x_moly_4_nm_gt_Vd_0p1, y_moly_4_nm_gt_Vd_0p1 , color='violet', linestyle='-', linewidth=3, label = 'V$_D$ = 0.1 V')
ax2.plot(x_moly_4_nm_gt_Vd_0p3, y_moly_4_nm_gt_Vd_0p3 , color='dodgerblue', linestyle='-', linewidth=3, label = 'V$_D$ = 0.3 V')
ax2.plot(x_moly_4_nm_gt_Vd_0p4, y_moly_4_nm_gt_Vd_0p4 , color='grey', linestyle='-', linewidth=3, label = 'V$_D$ = 0.4 V')
ax2.plot(x_moly_4_nm_gt_Vd_1, y_moly_4_nm_gt_Vd_1 , color='midnightblue', linestyle='-', linewidth=3, label = 'V$_D$ = 1 V')
ax2.plot(x_moly_4_nm_gt_Vd_3, y_moly_4_nm_gt_Vd_3 , color='forestgreen', linestyle='-', linewidth=3, label = 'V$_D$ = 3 V')



ax2.legend(loc='best',ncol=2, fontsize = 12)

plt.tight_layout()

plt.savefig("moly/Schottky_set/moly_4_nm_gate_different_Vd.png", bbox_inches = 'tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(10.5,5))

ax1 = fig.add_subplot(121)

ax1.set_xlabel('V$_g$ [V]', fontsize = 15)
ax1.set_ylabel('I$_d$ [A]', fontsize = 15)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
#from matplotlib import ticker
#formatter = ticker.ScalarFormatter(useMathText=True)
#formatter.set_scientific(True)
#formatter.set_powerlimits((-1,1))
#axes.yaxis.set_major_formatter(formatter)
ax1.set_xlim([0.01,3])
#ax1.set_ylim([1e-12, 1.4e-8])
#axes.grid('off')
#axes.set_yticks(axes.get_yticks()[::1])
#axes.set_xticks(axes.get_xticks()[::2])
ax1.text(1, 1e-6, "L$_g$ = 5 nm\nL$_c$ = L$_g$ + 100 nm", fontsize = 14)
#ax1.set_yscale('log')
ax1.plot(x_moly_5_nm_gt_Vd_0p1, y_moly_5_nm_gt_Vd_0p1 , color='violet', linestyle='-', linewidth=3, label = 'V$_D$ = 0.1 V')
ax1.plot(x_moly_5_nm_gt_Vd_0p3, y_moly_5_nm_gt_Vd_0p3 , color='dodgerblue', linestyle='-', linewidth=3, label = 'V$_D$ = 0.3 V')
ax1.plot(x_moly_5_nm_gt_Vd_0p4, y_moly_5_nm_gt_Vd_0p4 , color='grey', linestyle='-', linewidth=3, label = 'V$_D$ = 0.4 V')
ax1.plot(x_moly_5_nm_gt_Vd_1, y_moly_5_nm_gt_Vd_1 , color='midnightblue', linestyle='-', linewidth=3, label = 'V$_D$ = 1 V')
ax1.plot(x_moly_5_nm_gt_Vd_3, y_moly_5_nm_gt_Vd_3 , color='forestgreen', linestyle='-', linewidth=3, label = 'V$_D$ = 3 V')
#ax1.legend(loc='best',ncol=1, fontsize = 14)

ax2 = fig.add_subplot(122)

ax2.set_xlabel('V$_g$ [V]', fontsize = 15)
ax2.set_ylabel('I$_d$ [A]', fontsize = 15)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
#from matplotlib import ticker
#formatter = ticker.ScalarFormatter(useMathText=True)
#formatter.set_scientific(True)
#formatter.set_powerlimits((-1,1))
#axes.yaxis.set_major_formatter(formatter)
ax2.set_xlim([0.01,0.5])
ax2.set_ylim([5e-9, 1.23e-5])
#axes.grid('off')
#axes.set_yticks(axes.get_yticks()[::1])
#axes.set_xticks(axes.get_xticks()[::2])
#ax2.text(0.5, 3e-8, "V$_d$ = 0.1 V\nL$_c$ = L$_g$ + 100 nm", fontsize = 14)
ax2.set_yscale('log')
ax2.plot(x_moly_5_nm_gt_Vd_0p1, y_moly_5_nm_gt_Vd_0p1 , color='violet', linestyle='-', linewidth=3, label = 'V$_D$ = 0.1 V')
ax2.plot(x_moly_5_nm_gt_Vd_0p3, y_moly_5_nm_gt_Vd_0p3 , color='dodgerblue', linestyle='-', linewidth=3, label = 'V$_D$ = 0.3 V')
ax2.plot(x_moly_5_nm_gt_Vd_0p4, y_moly_5_nm_gt_Vd_0p4 , color='grey', linestyle='-', linewidth=3, label = 'V$_D$ = 0.4 V')
ax2.plot(x_moly_5_nm_gt_Vd_1, y_moly_5_nm_gt_Vd_1 , color='midnightblue', linestyle='-', linewidth=3, label = 'V$_D$ = 1 V')
ax2.plot(x_moly_5_nm_gt_Vd_3, y_moly_5_nm_gt_Vd_3 , color='forestgreen', linestyle='-', linewidth=3, label = 'V$_D$ = 3 V')



ax2.legend(loc='best',ncol=2, fontsize = 10)

plt.tight_layout()

plt.savefig("moly/Schottky_set/moly_5_nm_gate_different_Vd.png", bbox_inches = 'tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(10.5,5))

ax1 = fig.add_subplot(121)

ax1.set_xlabel('V$_g$ [V]', fontsize = 15)
ax1.set_ylabel('I$_d$ [A]', fontsize = 15)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
#from matplotlib import ticker
#formatter = ticker.ScalarFormatter(useMathText=True)
#formatter.set_scientific(True)
#formatter.set_powerlimits((-1,1))
#axes.yaxis.set_major_formatter(formatter)
ax1.set_xlim([0.01,3])
#ax1.set_ylim([1e-12, 1.4e-8])
#axes.grid('off')
#axes.set_yticks(axes.get_yticks()[::1])
#axes.set_xticks(axes.get_xticks()[::2])
ax1.text(1, 1e-6, "L$_g$ = 10 nm\nL$_c$ = L$_g$ + 100 nm", fontsize = 14)
#ax1.set_yscale('log')
ax1.plot(x_moly_10_nm_gt_Vd_0p1, y_moly_10_nm_gt_Vd_0p1 , color='violet', linestyle='-', linewidth=3, label = 'V$_D$ = 0.1 V')
ax1.plot(x_moly_10_nm_gt_Vd_0p3, y_moly_10_nm_gt_Vd_0p3 , color='dodgerblue', linestyle='-', linewidth=3, label = 'V$_D$ = 0.3 V')
ax1.plot(x_moly_10_nm_gt_Vd_0p4, y_moly_10_nm_gt_Vd_0p4 , color='grey', linestyle='-', linewidth=3, label = 'V$_D$ = 0.4 V')
ax1.plot(x_moly_10_nm_gt_Vd_1, y_moly_10_nm_gt_Vd_1 , color='midnightblue', linestyle='-', linewidth=3, label = 'V$_D$ = 1 V')
ax1.plot(x_moly_10_nm_gt_Vd_3, y_moly_10_nm_gt_Vd_3 , color='forestgreen', linestyle='-', linewidth=3, label = 'V$_D$ = 3 V')
#ax1.legend(loc='best',ncol=1, fontsize = 14)

ax2 = fig.add_subplot(122)

ax2.set_xlabel('V$_g$ [V]', fontsize = 15)
ax2.set_ylabel('I$_d$ [A]', fontsize = 15)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
#from matplotlib import ticker
#formatter = ticker.ScalarFormatter(useMathText=True)
#formatter.set_scientific(True)
#formatter.set_powerlimits((-1,1))
#axes.yaxis.set_major_formatter(formatter)
ax2.set_xlim([0.01,0.5])
ax2.set_ylim([1e-10, 1.23e-5])
#axes.grid('off')
#axes.set_yticks(axes.get_yticks()[::1])
#axes.set_xticks(axes.get_xticks()[::2])
#ax2.text(0.5, 3e-8, "V$_d$ = 0.1 V\nL$_c$ = L$_g$ + 100 nm", fontsize = 14)
ax2.set_yscale('log')
ax2.plot(x_moly_10_nm_gt_Vd_0p1, y_moly_10_nm_gt_Vd_0p1 , color='violet', linestyle='-', linewidth=3, label = 'V$_D$ = 0.1 V')
ax2.plot(x_moly_10_nm_gt_Vd_0p3, y_moly_10_nm_gt_Vd_0p3 , color='dodgerblue', linestyle='-', linewidth=3, label = 'V$_D$ = 0.3 V')
ax2.plot(x_moly_10_nm_gt_Vd_0p4, y_moly_10_nm_gt_Vd_0p4 , color='grey', linestyle='-', linewidth=3, label = 'V$_D$ = 0.4 V')
ax2.plot(x_moly_10_nm_gt_Vd_1, y_moly_10_nm_gt_Vd_1 , color='midnightblue', linestyle='-', linewidth=3, label = 'V$_D$ = 1 V')
ax2.plot(x_moly_10_nm_gt_Vd_3, y_moly_10_nm_gt_Vd_3 , color='forestgreen', linestyle='-', linewidth=3, label = 'V$_D$ = 3 V')



ax2.legend(loc='best',ncol=2, fontsize = 10)

plt.tight_layout()

plt.savefig("moly/Schottky_set/moly_10_nm_gate_different_Vd.png", bbox_inches = 'tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(10.5,5))

ax1 = fig.add_subplot(121)

ax1.set_xlabel('V$_g$ [V]', fontsize = 15)
ax1.set_ylabel('I$_d$ [A]', fontsize = 15)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
#from matplotlib import ticker
#formatter = ticker.ScalarFormatter(useMathText=True)
#formatter.set_scientific(True)
#formatter.set_powerlimits((-1,1))
#axes.yaxis.set_major_formatter(formatter)
ax1.set_xlim([0.01,3])
#ax1.set_ylim([1e-12, 1.4e-8])
#axes.grid('off')
#axes.set_yticks(axes.get_yticks()[::1])
#axes.set_xticks(axes.get_xticks()[::2])
ax1.text(1, 1e-6, "L$_g$ = 100 nm\nL$_c$ = L$_g$ + 100 nm", fontsize = 14)
#ax1.set_yscale('log')
ax1.plot(x_moly_100_nm_gt_Vd_0p1, y_moly_100_nm_gt_Vd_0p1 , color='violet', linestyle='-', linewidth=3, label = 'V$_D$ = 0.1 V')
ax1.plot(x_moly_100_nm_gt_Vd_0p3, y_moly_100_nm_gt_Vd_0p3 , color='dodgerblue', linestyle='-', linewidth=3, label = 'V$_D$ = 0.3 V')
ax1.plot(x_moly_100_nm_gt_Vd_0p4, y_moly_100_nm_gt_Vd_0p4 , color='grey', linestyle='-', linewidth=3, label = 'V$_D$ = 0.4 V')
ax1.plot(x_moly_100_nm_gt_Vd_1, y_moly_100_nm_gt_Vd_1 , color='midnightblue', linestyle='-', linewidth=3, label = 'V$_D$ = 1 V')
ax1.plot(x_moly_100_nm_gt_Vd_3, y_moly_100_nm_gt_Vd_3 , color='forestgreen', linestyle='-', linewidth=3, label = 'V$_D$ = 3 V')
#ax1.legend(loc='best',ncol=1, fontsize = 14)

ax2 = fig.add_subplot(122)

ax2.set_xlabel('V$_g$ [V]', fontsize = 15)
ax2.set_ylabel('I$_d$ [A]', fontsize = 15)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
#from matplotlib import ticker
#formatter = ticker.ScalarFormatter(useMathText=True)
#formatter.set_scientific(True)
#formatter.set_powerlimits((-1,1))
#axes.yaxis.set_major_formatter(formatter)
ax2.set_xlim([0.01,0.5])
ax2.set_ylim([1e-14, 1.23e-5])
#axes.grid('off')
#axes.set_yticks(axes.get_yticks()[::1])
#axes.set_xticks(axes.get_xticks()[::2])
#ax2.text(0.5, 3e-8, "V$_d$ = 0.1 V\nL$_c$ = L$_g$ + 100 nm", fontsize = 14)
ax2.set_yscale('log')
ax2.plot(x_moly_100_nm_gt_Vd_0p1, y_moly_100_nm_gt_Vd_0p1 , color='violet', linestyle='-', linewidth=3, label = 'V$_D$ = 0.1 V')
ax2.plot(x_moly_100_nm_gt_Vd_0p3, y_moly_100_nm_gt_Vd_0p3 , color='dodgerblue', linestyle='-', linewidth=3, label = 'V$_D$ = 0.3 V')
ax2.plot(x_moly_100_nm_gt_Vd_0p4, y_moly_100_nm_gt_Vd_0p4 , color='grey', linestyle='-', linewidth=3, label = 'V$_D$ = 0.4 V')
ax2.plot(x_moly_100_nm_gt_Vd_1, y_moly_100_nm_gt_Vd_1 , color='midnightblue', linestyle='-', linewidth=3, label = 'V$_D$ = 1 V')
ax2.plot(x_moly_100_nm_gt_Vd_3, y_moly_100_nm_gt_Vd_3 , color='forestgreen', linestyle='-', linewidth=3, label = 'V$_D$ = 3 V')



ax2.legend(loc='best',ncol=2, fontsize = 10)

plt.tight_layout()

plt.savefig("moly/Schottky_set/moly_100_nm_gate_different_Vd.png", bbox_inches = 'tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(10.5,5))

ax1 = fig.add_subplot(121)

ax1.set_xlabel('V$_g$ [V]', fontsize = 15)
ax1.set_ylabel('I$_d$ [A]', fontsize = 15)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
#from matplotlib import ticker
#formatter = ticker.ScalarFormatter(useMathText=True)
#formatter.set_scientific(True)
#formatter.set_powerlimits((-1,1))
#axes.yaxis.set_major_formatter(formatter)
ax1.set_xlim([0.01,3])
#ax1.set_ylim([1e-12, 1.4e-8])
#axes.grid('off')
#axes.set_yticks(axes.get_yticks()[::1])
#axes.set_xticks(axes.get_xticks()[::2])
ax1.text(1, 1e-6, "L$_g$ = 200 nm\nL$_c$ = L$_g$ + 100 nm", fontsize = 14)
#ax1.set_yscale('log')
ax1.plot(x_moly_200_nm_gt_Vd_1, y_moly_200_nm_gt_Vd_1 , color='midnightblue', linestyle='-', linewidth=3, label = 'V$_D$ = 1 V')
ax1.plot(x_moly_200_nm_gt_Vd_3, y_moly_200_nm_gt_Vd_3 , color='forestgreen', linestyle='-', linewidth=3, label = 'V$_D$ = 3 V')
#ax1.legend(loc='best',ncol=1, fontsize = 14)

ax2 = fig.add_subplot(122)

ax2.set_xlabel('V$_g$ [V]', fontsize = 15)
ax2.set_ylabel('I$_d$ [A]', fontsize = 15)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
#from matplotlib import ticker
#formatter = ticker.ScalarFormatter(useMathText=True)
#formatter.set_scientific(True)
#formatter.set_powerlimits((-1,1))
#axes.yaxis.set_major_formatter(formatter)
ax2.set_xlim([0.01,0.5])
ax2.set_ylim([1e-14, 1.23e-5])
#axes.grid('off')
#axes.set_yticks(axes.get_yticks()[::1])
#axes.set_xticks(axes.get_xticks()[::2])
#ax2.text(0.5, 3e-8, "V$_d$ = 0.1 V\nL$_c$ = L$_g$ + 100 nm", fontsize = 14)
ax2.set_yscale('log')
ax2.plot(x_moly_200_nm_gt_Vd_1, y_moly_200_nm_gt_Vd_1 , color='midnightblue', linestyle='-', linewidth=3, label = 'V$_D$ = 1 V')
ax2.plot(x_moly_200_nm_gt_Vd_3, y_moly_200_nm_gt_Vd_3 , color='forestgreen', linestyle='-', linewidth=3, label = 'V$_D$ = 3 V')



ax2.legend(loc='best',ncol=1, fontsize = 14)

plt.tight_layout()

plt.savefig("moly/Schottky_set/moly_200_nm_gate_different_Vd.png", bbox_inches = 'tight', dpi = 300)
plt.show()

# %%
oo_2_nm_Vd_0p1 = y_moly_2_nm_gt_Vd_0p1.iloc[-1]/y_moly_2_nm_gt_Vd_0p1.iloc[80]
oo_2_nm_Vd_0p3 = y_moly_2_nm_gt_Vd_0p3.iloc[-1]/y_moly_2_nm_gt_Vd_0p3.iloc[80]
oo_2_nm_Vd_0p4 = y_moly_2_nm_gt_Vd_0p4.iloc[-1]/y_moly_2_nm_gt_Vd_0p4.iloc[80]
oo_2_nm_Vd_1 = y_moly_2_nm_gt_Vd_1.iloc[-1]/y_moly_2_nm_gt_Vd_1.iloc[80]
oo_2_nm_Vd_3 = y_moly_2_nm_gt_Vd_3.iloc[-1]/y_moly_2_nm_gt_Vd_3.iloc[80]

oo_2_nm = [oo_2_nm_Vd_0p1,oo_2_nm_Vd_0p3,oo_2_nm_Vd_0p4,oo_2_nm_Vd_1,oo_2_nm_Vd_3]

oo_3_nm_Vd_0p1 = y_moly_3_nm_gt_Vd_0p1.iloc[-1]/y_moly_3_nm_gt_Vd_0p1.iloc[80]
oo_3_nm_Vd_0p3 = y_moly_3_nm_gt_Vd_0p3.iloc[-1]/y_moly_3_nm_gt_Vd_0p3.iloc[80]
oo_3_nm_Vd_0p4 = y_moly_3_nm_gt_Vd_0p4.iloc[-1]/y_moly_3_nm_gt_Vd_0p4.iloc[80]
oo_3_nm_Vd_1 = y_moly_3_nm_gt_Vd_1.iloc[-1]/y_moly_3_nm_gt_Vd_1.iloc[80]
oo_3_nm_Vd_3 = y_moly_3_nm_gt_Vd_3.iloc[-1]/y_moly_3_nm_gt_Vd_3.iloc[80]

oo_3_nm = [oo_3_nm_Vd_0p1,oo_3_nm_Vd_0p3,oo_3_nm_Vd_0p4,oo_3_nm_Vd_1,oo_3_nm_Vd_3]

oo_4_nm_Vd_0p1 = y_moly_4_nm_gt_Vd_0p1.iloc[-1]/y_moly_4_nm_gt_Vd_0p1.iloc[80]
oo_4_nm_Vd_0p3 = y_moly_4_nm_gt_Vd_0p3.iloc[-1]/y_moly_4_nm_gt_Vd_0p3.iloc[80]
oo_4_nm_Vd_0p4 = y_moly_4_nm_gt_Vd_0p4.iloc[-1]/y_moly_4_nm_gt_Vd_0p4.iloc[80]
oo_4_nm_Vd_1 = y_moly_4_nm_gt_Vd_1.iloc[-1]/y_moly_4_nm_gt_Vd_1.iloc[80]
oo_4_nm_Vd_3 = y_moly_4_nm_gt_Vd_3.iloc[-1]/y_moly_4_nm_gt_Vd_3.iloc[80]

oo_4_nm = [oo_4_nm_Vd_0p1,oo_4_nm_Vd_0p3,oo_4_nm_Vd_0p4,oo_4_nm_Vd_1,oo_4_nm_Vd_3]

oo_5_nm_Vd_0p1 = y_moly_5_nm_gt_Vd_0p1.iloc[-1]/y_moly_5_nm_gt_Vd_0p1.iloc[80]
oo_5_nm_Vd_0p3 = y_moly_5_nm_gt_Vd_0p3.iloc[-1]/y_moly_5_nm_gt_Vd_0p3.iloc[80]
oo_5_nm_Vd_0p4 = y_moly_5_nm_gt_Vd_0p4.iloc[-1]/y_moly_5_nm_gt_Vd_0p4.iloc[80]
oo_5_nm_Vd_1 = y_moly_5_nm_gt_Vd_1.iloc[-1]/y_moly_5_nm_gt_Vd_1.iloc[80]
oo_5_nm_Vd_3 = y_moly_5_nm_gt_Vd_3.iloc[-1]/y_moly_5_nm_gt_Vd_3.iloc[80]

oo_5_nm = [oo_5_nm_Vd_0p1,oo_5_nm_Vd_0p3,oo_5_nm_Vd_0p4,oo_5_nm_Vd_1,oo_5_nm_Vd_3]

oo_10_nm_Vd_0p1 = y_moly_10_nm_gt_Vd_0p1.iloc[-1]/y_moly_10_nm_gt_Vd_0p1.iloc[80]
oo_10_nm_Vd_0p3 = y_moly_10_nm_gt_Vd_0p3.iloc[-1]/y_moly_10_nm_gt_Vd_0p3.iloc[80]
oo_10_nm_Vd_0p4 = y_moly_10_nm_gt_Vd_0p4.iloc[-1]/y_moly_10_nm_gt_Vd_0p4.iloc[80]
oo_10_nm_Vd_1 = y_moly_10_nm_gt_Vd_1.iloc[-1]/y_moly_10_nm_gt_Vd_1.iloc[80]
oo_10_nm_Vd_3 = y_moly_10_nm_gt_Vd_3.iloc[-1]/y_moly_10_nm_gt_Vd_3.iloc[80]

oo_10_nm = [oo_10_nm_Vd_0p1,oo_10_nm_Vd_0p3,oo_10_nm_Vd_0p4,oo_10_nm_Vd_1,oo_10_nm_Vd_3]

oo_100_nm_Vd_0p1 = y_moly_100_nm_gt_Vd_0p1.iloc[-1]/y_moly_100_nm_gt_Vd_0p1.iloc[80]
oo_100_nm_Vd_0p3 = y_moly_100_nm_gt_Vd_0p3.iloc[-1]/y_moly_100_nm_gt_Vd_0p3.iloc[80]
oo_100_nm_Vd_0p4 = y_moly_100_nm_gt_Vd_0p4.iloc[-1]/y_moly_100_nm_gt_Vd_0p4.iloc[80]
oo_100_nm_Vd_1 = y_moly_100_nm_gt_Vd_1.iloc[-1]/y_moly_100_nm_gt_Vd_1.iloc[80]
oo_100_nm_Vd_3 = y_moly_100_nm_gt_Vd_3.iloc[-1]/y_moly_100_nm_gt_Vd_3.iloc[80]

oo_100_nm = [oo_100_nm_Vd_0p1,oo_100_nm_Vd_0p3,oo_100_nm_Vd_0p4,oo_100_nm_Vd_1,oo_100_nm_Vd_3]

Vds = [0.1, 0.3, 0.4, 1, 3]
Lg = [2, 3, 4, 5, 10, 100]

# %%
fig = plt.figure(figsize=(6,6))


ax2 = fig.add_subplot(111)

ax2.set_xlabel('V$_D$ [V]', fontsize = 15)
ax2.set_ylabel('On/off ratio', fontsize = 15)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
#from matplotlib import ticker
#formatter = ticker.ScalarFormatter(useMathText=True)
#formatter.set_scientific(True)
#formatter.set_powerlimits((-1,1))
#axes.yaxis.set_major_formatter(formatter)
ax2.set_xlim([0.05,0.45])
ax2.set_ylim([0.11, 1e2])
#axes.grid('off')
#axes.set_yticks(axes.get_yticks()[::1])
#axes.set_xticks(axes.get_xticks()[::2])
#ax2.text(1, 1e-6, "L$_g$ = 200 nm\nL$_c$ = L$_g$ + 100 nm", fontsize = 14)
ax2.set_yscale('log')
ax2.plot(Vds,oo_2_nm, '--o',ms = 14, mew = 1, mec = 'black',color = 'orange', label = '2 nm')
ax2.plot(Vds,oo_3_nm, '--o',ms = 14, mew = 1, mec = 'black',color = 'grey', label = '3 nm')
ax2.plot(Vds,oo_4_nm, '--o',ms = 14, color = 'black', mew = 1, mfc = 'white', mec = 'black', label = '4 nm')
ax2.plot(Vds,oo_5_nm, '--o',ms = 14, mew = 1, mec = 'black',color = 'g', label = '5 nm')
ax2.plot(Vds,oo_10_nm, '--o',ms = 14, mew = 1, mec = 'black',color = 'b', label = '10 nm')
ax2.plot(Vds,oo_100_nm, '--o',ms = 14, mew = 1, mec = 'black',color = 'r', label = '100 nm')
ax2.axvspan(0.27, 0.35, color='dodgerblue', alpha=0.5)
ax2.axvline(0.27, c = 'black')
ax2.axvline(0.35, c = 'black')
ax2.legend(loc='best',ncol=2, fontsize = 12)

plt.tight_layout()
plt.savefig("moly/Schottky_set/moly_on_offs_as_fnxn_of_Vd.png", bbox_inches = 'tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(5,8))
fig.canvas.draw()

ax1 = fig.add_subplot(616)
ax1.plot(Vds,oo_2_nm, '--o',ms = 10, mew = 0.75, mec = 'black',color = 'orange', label = '2 nm',clip_on=False)
ax1.set_xlabel('V$_D$ [V]', fontsize = 10)
ax1.set_ylabel('On/off ratio', fontsize = 10)
#plt.yticks(fontsize = 14)
#plt.xticks(fontsize = 14)
#plt.ticklabel_format(style='sci', axis='y')
ax1.legend(loc='best')
plt.rcParams["font.family"] = "monospace"
#from matplotlib import ticker
#formatter = ticker.ScalarFormatter(useMathText=True)
#formatter.set_scientific(True)
#formatter.set_powerlimits((-1,1))
#axes.yaxis.set_major_formatter(formatter)
#ax1.set_xlim([0.1,0.4])
#ax1.set_ylim([1e-12, 1.4e-8])
#axes.grid('off')
#axes.set_yticks(axes.get_yticks()[::1])
#axes.set_xticks(axes.get_xticks()[::2])
#ax1.text(1, 1e-6, "L$_g$ = 200 nm\nL$_c$ = L$_g$ + 100 nm", fontsize = 14)
#ax1.set_yscale('log')



#ax1.legend(loc='best',ncol=2, fontsize = 12)

ax2 = fig.add_subplot(615)
ax2.plot(Vds,oo_3_nm, '--o',ms = 10, mew = 0.75, mec = 'black',color = 'grey', label = '3 nm',clip_on=False)
#plt.ticklabel_format(style='sci', axis='y')
#ax2.set_yscale('log')
#ax2.set_xlabel('V$_D$ [V]', fontsize = 15)
ax2.set_ylabel('On/off ratio', fontsize = 10)
#plt.yticks(fontsize = 14)
#plt.xticks(fontsize = 14)
ax2.legend(loc='best')
plt.rcParams["font.family"] = "monospace"



ax3 = fig.add_subplot(614)
ax3.plot(Vds,oo_4_nm, '--o',ms = 10, mew = 0.75, mec = 'black',color = 'black', label = '4 nm',clip_on=False)
#plt.ticklabel_format(style='sci', axis='y')
#ax3.set_yscale('log')
#ax3.set_xlabel('V$_D$ [V]', fontsize = 15)
ax3.set_ylabel('On/off ratio', fontsize = 10)
#plt.yticks(fontsize = 14)
#plt.xticks(fontsize = 14)
ax3.legend(loc='best')
plt.rcParams["font.family"] = "monospace"



ax4 = fig.add_subplot(613)
ax4.plot(Vds,oo_5_nm, '--o',ms = 10, mew = 0.75, mec = 'black',color = 'g', label = '5 nm',clip_on=False)
#plt.ticklabel_format(style='sci', axis='y')
#ax4.set_yscale('log')
#ax4.set_xlabel('V$_D$ [V]', fontsize = 10)
ax4.set_ylabel('On/off ratio', fontsize = 10)
#plt.yticks(fontsize = 14)
#plt.xticks(fontsize = 14)
ax4.legend(loc='best')
plt.rcParams["font.family"] = "monospace"


ax5 = fig.add_subplot(612)
ax5.plot(Vds,oo_10_nm, '--o',ms = 10, mew = 0.75, mec = 'black',color = 'b', label = '10 nm',clip_on=False)
#plt.ticklabel_format(style='sci', axis='y')
#ax5.set_yscale('log')
#ax5.set_xlabel('V$_D$ [V]', fontsize = 15)
ax5.set_ylabel('On/off ratio', fontsize = 10)
#plt.yticks(fontsize = 14)
#plt.xticks(fontsize = 14)
ax5.legend(loc='best')
plt.rcParams["font.family"] = "monospace"


ax6 = fig.add_subplot(611)
ax6.plot(Vds,oo_100_nm, '--o',ms = 10, mew = 0.75, mec = 'black',color = 'r', label = '100 nm',clip_on=False)
#plt.ticklabel_format(style='sci', axis='y')
ax6.set_yscale('log')
#ax6.set_xlabel('V$_D$ [V]', fontsize = 10)
ax6.set_ylabel('On/off ratio', fontsize = 10)
##plt.yticks(fontsize = 14)
#plt.xticks(fontsize = 14)
ax6.legend(loc='lower right')

plt.rcParams["font.family"] = "monospace"
fig.subplots_adjust(hspace=0.1)
plt.tight_layout()
plt.savefig("moly/Schottky_set/moly_on_offs_as_fnxn_of_Vd_separate.png", bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(15,8))

ax1 = fig.add_subplot(321)

ax1.set_xlabel('$x$ coordinate [$\mu$m]', fontsize = 12)
ax1.set_ylabel('Energy [eV]', fontsize = 12)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
#from matplotlib import ticker
#formatter = ticker.ScalarFormatter(useMathText=True)
#formatter.set_scientific(True)
#formatter.set_powerlimits((-1,1))
#axes.yaxis.set_major_formatter(formatter)
#ax1.set_xlim([0.01,3])
#ax1.set_ylim([5e-6, 3e-4])
ax1.grid('off')
#ax1.set_yticks(axes.get_yticks()[::1])
#ax1.set_xticks(axes.get_xticks()[::2])
#ax1.text(0.25, 7.5e-5, "V$_d$ = 3 V\nL$_c$ = 60 nm", fontsize = 14)
#ax1.set_yscale('log')
ax1.plot(Ec_x_moly_2_nm_gt_Vd_0p3_bs, Ec_y_moly_2_nm_gt_Vd_0p3_bs, color='forestgreen', linestyle='-', linewidth=3, label = 'E$_c$')
ax1.plot(Ev_x_moly_2_nm_gt_Vd_0p3_bs, Ev_y_moly_2_nm_gt_Vd_0p3_bs, color='steelblue', linestyle='-', linewidth=3, label = 'E$_v$')
ax1.plot(Efn_x_moly_2_nm_gt_Vd_0p3_bs, Efn_y_moly_2_nm_gt_Vd_0p3_bs, color='olive', linestyle=':', linewidth=3, label = 'E$_{fn}$')
ax1.plot(Efp_x_moly_2_nm_gt_Vd_0p3_bs, Efp_y_moly_2_nm_gt_Vd_0p3_bs, color='midnightblue', linestyle=':', linewidth=3, label = 'E$_{fp}$')
#ax1.axvline(0.14, color = 'black')
#ax1.axvline(0.15, color = 'black')
ax1.legend(loc='center',ncol=4, fontsize = 14)

ax2 = fig.add_subplot(322)

ax2.set_xlabel('$x$ coordinate [$\mu$m]', fontsize = 12)
ax2.set_ylabel('$v_e$ [cm s$^{-1}$]', fontsize = 12)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
#from matplotlib import ticker
#formatter = ticker.ScalarFormatter(useMathText=True)
#formatter.set_scientific(True)
#formatter.set_powerlimits((-1,1))
#axes.yaxis.set_major_formatter(formatter)
#ax2.set_xlim([0.01,3])
#ax2.set_ylim([5e-6, 3e-4])
ax2.grid('off')
#ax2.set_yticks(axes.get_yticks()[::1])
#ax2.set_xticks(axes.get_xticks()[::2])
#ax2.text(0.25, 7.5e-5, "V$_d$ = 3 V\nL$_c$ = 60 nm", fontsize = 14)
#ax2.set_yscale('log')

ax2.plot(x_moly_2_nm_gt_Vd_0p3_ev, y_moly_2_nm_gt_Vd_0p3_ev, color='steelblue', linestyle='-', linewidth=3, label = 'L$_g$ = 2 nm')

#ax2.axvline(0.14, color = 'black')
#ax2.axvline(0.15, color = 'black')
ax2.legend(loc='upper left',ncol=4, fontsize = 14)

ax3 = fig.add_subplot(323)

ax3.set_xlabel('$x$ coordinate [$\mu$m]', fontsize = 12)
ax3.set_ylabel('$\mu_e$ [cm$^2$ V$^{-1}$ s$^{-1}$]', fontsize = 12)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
#from matplotlib import ticker
#formatter = ticker.ScalarFormatter(useMathText=True)
#formatter.set_scientific(True)
#formatter.set_powerlimits((-1,1))
#axes.yaxis.set_major_formatter(formatter)
#ax3.set_xlim([0.01,3])
#ax3.set_ylim([5e-6, 3e-4])
ax3.grid('off')
#ax3.set_yticks(axes.get_yticks()[::1])
#ax3.set_xticks(axes.get_xticks()[::2])
#ax3.text(0.25, 7.5e-5, "V$_d$ = 3 V\nL$_c$ = 60 nm", fontsize = 14)
#ax3.set_yscale('log')

ax3.plot(x_moly_2_nm_gt_Vd_0p3_em, y_moly_2_nm_gt_Vd_0p3_em, color='red', linestyle='-', linewidth=3, label = 'L$_g$ = 2 nm')

#ax3.axvline(0.14, color = 'black')
#ax3.axvline(0.15, color = 'black')
ax3.legend(loc='lower left',ncol=4, fontsize = 14)

ax4 = fig.add_subplot(324)

ax4.set_xlabel('$x$ coordinate [$\mu$m]', fontsize = 12)
ax4.set_ylabel('$\phi$ [V]', fontsize = 12)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
#from matplotlib import ticker
#formatter = ticker.ScalarFormatter(useMathText=True)
#formatter.set_scientific(True)
#formatter.set_powerlimits((-1,1))
#axes.yaxis.set_major_formatter(formatter)
#ax4.set_xlim([0.01,3])
#ax4.set_ylim([5e-6, 3e-4])
ax4.grid('off')
#ax4.set_yticks(axes.get_yticks()[::1])
#ax4.set_xticks(axes.get_xticks()[::2])
#ax4.text(0.25, 7.5e-5, "V$_d$ = 3 V\nL$_c$ = 60 nm", fontsize = 14)
#ax4.set_yscale('log')

ax4.plot(x_moly_2_nm_gt_Vd_0p3_ep, y_moly_2_nm_gt_Vd_0p3_ep, color='midnightblue', linestyle='-', linewidth=3, label = 'L$_g$ = 2 nm')

#ax4.axvline(0.14, color = 'black')
#ax4.axvline(0.15, color = 'black')
ax4.legend(loc='lower right',ncol=4, fontsize = 14)

ax5 = fig.add_subplot(325)

ax5.set_xlabel('$x$ coordinate [$\mu$m]', fontsize = 12)
ax5.set_ylabel('Trap occupation [cm $^{-3}$ eV$^{-1}$]', fontsize = 12)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
#from matplotlib import ticker
#formatter = ticker.ScalarFormatter(useMathText=True)
#formatter.set_scientific(True)
#formatter.set_powerlimits((-1,1))
#axes.yaxis.set_major_formatter(formatter)
#ax5.set_xlim([0.01,3])
#ax5.set_ylim([5e-6, 3e-4])
ax5.grid('off')
#ax5.set_yticks(axes.get_yticks()[::1])
#ax5.set_xticks(axes.get_xticks()[::2])
#ax5.text(0.25, 7.5e-5, "V$_d$ = 3 V\nL$_c$ = 60 nm", fontsize = 14)
#ax5.set_yscale('log')

ax5.plot(x_moly_2_nm_gt_Vd_0p3_to, y_moly_2_nm_gt_Vd_0p3_to, color='purple', linestyle='-', linewidth=3, label = 'L$_g$ = 2 nm')

#ax5.axvline(0.14, color = 'black')
#ax5.axvline(0.15, color = 'black')
ax5.legend(loc='upper right',ncol=4, fontsize = 14)

ax6 = fig.add_subplot(326)

ax6.set_xlabel('$x$ coordinate [$\mu$m]', fontsize = 12)
ax6.set_ylabel('Electric field [V cm $^{-1}$]', fontsize = 12)
plt.yticks(fontsize = 14)
plt.xticks(fontsize = 14)
plt.ticklabel_format(style='sci', axis='y')

plt.rcParams["font.family"] = "monospace"
#from matplotlib import ticker
#formatter = ticker.ScalarFormatter(useMathText=True)
#formatter.set_scientific(True)
#formatter.set_powerlimits((-1,1))
#axes.yaxis.set_major_formatter(formatter)
#ax5.set_xlim([0.01,3])
#ax5.set_ylim([5e-6, 3e-4])
ax6.grid('off')
#ax5.set_yticks(axes.get_yticks()[::1])
#ax5.set_xticks(axes.get_xticks()[::2])
#ax5.text(0.25, 7.5e-5, "V$_d$ = 3 V\nL$_c$ = 60 nm", fontsize = 14)
#ax5.set_yscale('log')

ax6.plot(x_moly_2_nm_gt_Vd_0p3_ef, y_moly_2_nm_gt_Vd_0p3_ef, color='grey', linestyle='-', linewidth=3, label = 'L$_g$ = 2 nm')

#ax6.axvline(0.14, color = 'black')
#ax6.axvline(0.15, color = 'black')
ax6.legend(loc='upper right',ncol=4, fontsize = 14)

plt.tight_layout()

plt.savefig("moly/Schottky_set/2_nm/moly_2_nm_gate_Vd_0p3_profiles.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
max(y_moly_2_nm_gt_Vd_0p3_ef)-min(y_moly_2_nm_gt_Vd_0p3_ef)
# Out:
# 985924.0876999999
